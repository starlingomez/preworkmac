# %% [markdown]
# <a href="https://colab.research.google.com/github/starlingomez/preworkmac/blob/master/SEPTIEMBRE21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #JARRED JONES

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [23, 25, 24, 16, 24, 20, 22, 27, 25, 25, 21, 24, 24, 23, 28, 20, 19, 25, 25, 20],
    'K%': [0.435, 0.28, 0.333, 0.438, 0.292, 0.15, 0.455, 0.148, 0.28, 0.2, 0.095, 0.25, 0.125, 0.261, 0.286, 0.25, 0.211, 0.16, 0.36, 0.25],
    'STRIKEOUT': [10, 7, 8, 7, 7, 3, 10, 4, 7, 5, 2, 6, 3, 6, 8, 5, 4, 4, 9, 5]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22],    # Example TBF
    'K%': [0.2465]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6 7]
# Predicted Strikeouts: [6.94 7.   7.  ]
# Actual Strikeouts: [ 3 10  4]
# Mean Squared Error: 11.179363178679901
#
# Test Indices: [ 8  9 10]
# Predicted Strikeouts: [7. 4. 3.]
# Actual Strikeouts: [7 5 2]
# Mean Squared Error: 0.6678426876318705
#
# Test Indices: [11 12 13]
# Predicted Strikeouts: [5.   2.97 5.14]
# Actual Strikeouts: [6 3 6]
# Mean Squared Error: 0.5789608142491337
#
# Test Indices: [14 15 16]
# Predicted Strikeouts: [7.  6.  4.1]
# Actual Strikeouts: [8 5 4]
# Mean Squared Error: 0.6695925834025426
#
# Test Indices: [17 18 19]
# Predicted Strikeouts: [4.11 8.09 5.  ]
# Actual Strikeouts: [4 9 5]
# Mean Squared Error: 0.2820679914129869
#
# Average Mean Squared Error across all folds: 2.675565451075287
# Predicted Strikeouts for Next Game: 4.628496170043945

# %% [markdown]
# #MACKENZIE GORE

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [25, 21, 19, 20, 23, 23, 18, 27, 23, 26, 22, 24, 22, 28, 27, 24, 22, 21, 20, 12, 25, 24, 27, 22, 26, 24, 26, 20, 23, 22],
    'K%': [0.24, 0.286, 0.579, 0.2, 0.174, 0.304, 0.222, 0.333, 0.13, 0.308, 0.455, 0.083, 0.318, 0.357, 0.259, 0.042, 0.364, 0.238, 0.2, 0.167, 0.12, 0.042, 0.222, 0.091, 0.231, 0.167, 0.231, 0.45, 0.13, 0.227],
    'STRIKEOUT': [6, 6, 11, 4, 4, 7, 4, 9, 3, 8, 10, 2, 7, 10, 7, 1, 8, 5, 4, 2, 3, 1, 6, 2, 6, 4, 6, 9, 3, 5]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.2410]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6 7 8 9]
# Predicted Strikeouts: [ 6. 11.  6.  4.  6.]
# Actual Strikeouts: [7 4 9 3 8]
# Mean Squared Error: 12.796397679185612
#
# Test Indices: [10 11 12 13 14]
# Predicted Strikeouts: [9.   3.   7.89 9.   6.01]
# Actual Strikeouts: [10  2  7 10  7]
# Mean Squared Error: 0.9559303739948973
#
# Test Indices: [15 16 17 18 19]
# Predicted Strikeouts: [ 2. 10.  4.  4.  3.]
# Actual Strikeouts: [1 8 5 4 2]
# Mean Squared Error: 1.4002220406401762
#
# Test Indices: [20 21 22 23 24]
# Predicted Strikeouts: [2.02 1.   3.63 2.85 3.63]
# Actual Strikeouts: [3 1 6 2 6]
# Mean Squared Error: 2.584866129216448
#
# Test Indices: [25 26 27 28 29]
# Predicted Strikeouts: [2.76 6.   8.   3.   4.01]
# Actual Strikeouts: [4 6 9 3 5]
# Mean Squared Error: 0.7033502641716154
#
# Average Mean Squared Error across all folds: 3.6881532974417497
# Predicted Strikeouts for Next Game: 5.83957576751709

# %% [markdown]
# #KYLE HENDRICKS

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [21, 22, 23, 22, 18, 20, 25, 20, 26, 19, 11, 24, 22, 23, 19, 23, 21, 22, 16, 20, 21, 23],
    'K%': [0.095, 0.182, 0.087, 0.136, 0.278, 0.25, 0.16, 0.4, 0.154, 0.158, 0.091, 0.125, 0.091, 0.174, 0.211, 0.217, 0.095, 0, 0.125, 0.25, 0.095, 0.304],
    'STRIKEOUT': [2, 4, 2, 3, 5, 5, 4, 8, 4, 3, 1, 3, 2, 4, 4, 5, 2, 0, 2, 5, 2, 7]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [20],    # Example TBF
    'K%': [0.1548]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [7 8 9]
# Predicted Strikeouts: [5. 3. 3.]
# Actual Strikeouts: [8 4 3]
# Mean Squared Error: 3.334487293889746
#
# Test Indices: [10 11 12]
# Predicted Strikeouts: [2.   2.   2.01]
# Actual Strikeouts: [1 3 2]
# Mean Squared Error: 0.6629688093957498
#
# Test Indices: [13 14 15]
# Predicted Strikeouts: [3.89 4.39 4.  ]
# Actual Strikeouts: [4 4 5]
# Mean Squared Error: 0.3869902808675458
#
# Test Indices: [16 17 18]
# Predicted Strikeouts: [2.   2.   2.25]
# Actual Strikeouts: [2 0 2]
# Mean Squared Error: 1.3549170668168433
#
# Test Indices: [19 20 21]
# Predicted Strikeouts: [5. 2. 5.]
# Actual Strikeouts: [5 2 7]
# Mean Squared Error: 1.3332169969149656
#
# Average Mean Squared Error across all folds: 1.4145160895769702
# Predicted Strikeouts for Next Game: 3.3799195289611816

# %% [markdown]
# #CADE POVICH

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [25, 24, 20, 24, 21, 11, 24, 26, 25, 24, 21, 27, 21, 19],
    'K%': [0.08, 0.25, 0.05, 0.208, 0.143, 0.091, 0.25, 0.038, 0.24, 0.125, 0.143, 0.37, 0.238, 0.421],
    'STRIKEOUT': [2, 6, 1, 5, 3, 1, 6, 1, 6, 3, 3, 10, 5, 8]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22],    # Example TBF
    'K%': [0.2594]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [4 5]
# Predicted Strikeouts: [1. 1.]
# Actual Strikeouts: [3 1]
# Mean Squared Error: 1.9977967966825076
#
# Test Indices: [6 7]
# Predicted Strikeouts: [6. 2.]
# Actual Strikeouts: [6 1]
# Mean Squared Error: 0.5000194329933549
#
# Test Indices: [8 9]
# Predicted Strikeouts: [5. 2.]
# Actual Strikeouts: [6 3]
# Mean Squared Error: 1.0012026466475845
#
# Test Indices: [10 11]
# Predicted Strikeouts: [3. 6.]
# Actual Strikeouts: [ 3 10]
# Mean Squared Error: 8.0089517892159
#
# Test Indices: [12 13]
# Predicted Strikeouts: [4.94 5.97]
# Actual Strikeouts: [5 8]
# Mean Squared Error: 2.0612215937726432
#
# Average Mean Squared Error across all folds: 2.713838451862398
# Predicted Strikeouts for Next Game: 5.99987268447876

# %% [markdown]
# #RANGER SUAREZ

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [18, 23, 22, 32, 23, 26, 27, 25, 23, 27, 25, 6, 27, 27, 23, 26, 26, 24, 27, 24, 19, 18, 19, 29, 22],
    'K%': [0.389, 0.174, 0.364, 0.25, 0.217, 0.308, 0.222, 0.36, 0.13, 0.37, 0.36, 0.333, 0.222, 0.222, 0.174, 0.154, 0, 0.292, 0.222, 0.167, 0.316, 0.333, 0.211, 0.069, 0.227],
    'STRIKEOUT': [7, 4, 8, 8, 5, 8, 6, 9, 3, 10, 9, 2, 6, 6, 4, 4, 0, 7, 6, 4, 6, 6, 4, 2, 5]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [21],    # Example TBF
    'K%': [0.2312]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6 7 8]
# Predicted Strikeouts: [8. 5. 8. 4.]
# Actual Strikeouts: [8 6 9 3]
# Mean Squared Error: 0.7508417161183729
#
# Test Indices: [ 9 10 11 12]
# Predicted Strikeouts: [8.29 9.   7.02 6.  ]
# Actual Strikeouts: [10  9  2  6]
# Mean Squared Error: 7.034552561357714
#
# Test Indices: [13 14 15 16]
# Predicted Strikeouts: [6.   4.   4.87 4.87]
# Actual Strikeouts: [6 4 4 0]
# Mean Squared Error: 6.108181323838792
#
# Test Indices: [17 18 19 20]
# Predicted Strikeouts: [6.64 6.   3.75 5.98]
# Actual Strikeouts: [7 6 4 6]
# Mean Squared Error: 0.04808838363261714
#
# Test Indices: [21 22 23 24]
# Predicted Strikeouts: [6.56 4.   0.   5.84]
# Actual Strikeouts: [6 4 2 5]
# Mean Squared Error: 1.2557312746193983
#
# Average Mean Squared Error across all folds: 3.039479051913379
# Predicted Strikeouts for Next Game: 5.219642162322998

# %% [markdown]
# #SEAN MANANEA

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [20, 21, 24, 21, 21, 21, 24, 23, 21, 21, 25, 19, 19, 23, 19, 29, 22, 27, 24, 22, 24, 28, 18, 27, 25, 25, 24, 24, 27, 25],
    'K%': [0.4, 0.286, 0.167, 0.143, 0.286, 0.143, 0.042, 0.261, 0.19, 0.286, 0.4, 0.158, 0.368, 0.261, 0.158, 0.172, 0.273, 0.333, 0.042, 0.182, 0.458, 0.357, 0.167, 0.148, 0.36, 0.44, 0.208, 0.375, 0.296, 0.24],
    'STRIKEOUT': [8, 6, 4, 3, 6, 3, 1, 6, 4, 6, 10, 3, 7, 6, 3, 5, 6, 9, 1, 4, 11, 10, 3, 4, 9, 11, 5, 9, 8, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [25],    # Example TBF
    'K%': [0.3118]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6 7 8 9]
# Predicted Strikeouts: [3.   3.99 3.02 3.02 6.  ]
# Actual Strikeouts: [3 1 6 4 6]
# Mean Squared Error: 3.7574084434067343
#
# Test Indices: [10 11 12 13 14]
# Predicted Strikeouts: [6.   3.42 8.   6.   3.42]
# Actual Strikeouts: [10  3  7  6  3]
# Mean Squared Error: 3.4692233566464212
#
# Test Indices: [15 16 17 18 19]
# Predicted Strikeouts: [4.01 6.   6.87 1.   4.  ]
# Actual Strikeouts: [5 6 9 1 4]
# Mean Squared Error: 1.103626553736524
#
# Test Indices: [20 21 22 23 24]
# Predicted Strikeouts: [10.    9.    4.    3.64  9.  ]
# Actual Strikeouts: [11 10  3  4  9]
# Mean Squared Error: 0.627590275266823
#
# Test Indices: [25 26 27 28 29]
# Predicted Strikeouts: [10.    4.39  9.82  7.46  4.33]
# Actual Strikeouts: [11  5  9  8  6]
# Mean Squared Error: 1.022029187104272
#
# Average Mean Squared Error across all folds: 1.9959755632321545
# Predicted Strikeouts for Next Game: 7.815518856048584

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [20, 21, 24, 21, 21, 21, 24, 23, 21, 21, 25, 19, 19, 23, 19, 29, 22, 27, 24, 22, 24, 28, 18, 27, 25, 25, 24, 24, 27, 25],
    'K%': [0.4, 0.286, 0.167, 0.143, 0.286, 0.143, 0.042, 0.261, 0.19, 0.286, 0.4, 0.158, 0.368, 0.261, 0.158, 0.172, 0.273, 0.333, 0.042, 0.182, 0.458, 0.357, 0.167, 0.148, 0.36, 0.44, 0.208, 0.375, 0.296, 0.24],
    'STRIKEOUT': [8, 6, 4, 3, 6, 3, 1, 6, 4, 6, 10, 3, 7, 6, 3, 5, 6, 9, 1, 4, 11, 10, 3, 4, 9, 11, 5, 9, 8, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [25],    # Example TBF
    'K%': [0.2560]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6 7 8 9]
# Predicted Strikeouts: [3.   3.99 3.02 3.02 6.  ]
# Actual Strikeouts: [3 1 6 4 6]
# Mean Squared Error: 3.7574084434067343
#
# Test Indices: [10 11 12 13 14]
# Predicted Strikeouts: [6.   3.42 8.   6.   3.42]
# Actual Strikeouts: [10  3  7  6  3]
# Mean Squared Error: 3.4692233566464212
#
# Test Indices: [15 16 17 18 19]
# Predicted Strikeouts: [4.01 6.   6.87 1.   4.  ]
# Actual Strikeouts: [5 6 9 1 4]
# Mean Squared Error: 1.103626553736524
#
# Test Indices: [20 21 22 23 24]
# Predicted Strikeouts: [10.    9.    4.    3.64  9.  ]
# Actual Strikeouts: [11 10  3  4  9]
# Mean Squared Error: 0.627590275266823
#
# Test Indices: [25 26 27 28 29]
# Predicted Strikeouts: [10.    4.39  9.82  7.46  4.33]
# Actual Strikeouts: [11  5  9  8  6]
# Mean Squared Error: 1.022029187104272
#
# Average Mean Squared Error across all folds: 1.9959755632321545
# Predicted Strikeouts for Next Game: 5.999919414520264

# %% [markdown]
# #YARIEL RODRIGUEZ

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    "TBF": [16, 16, 20, 20, 9, 4, 23, 20, 19, 20, 9, 19, 23, 21, 19, 24, 13, 17, 17],
    "K%": [0.375, 0.438, 0.1, 0.05, 0.111, 0, 0.261, 0.3, 0.368, 0.3, 0.111, 0.211, 0.217, 0.238, 0.316, 0.125, 0.231, 0.353, 0.118],
    "STRIKEOUT": [6, 7, 2, 1, 1, 0, 6, 6, 7, 6, 1, 4, 5, 5, 6, 3, 3, 6, 2]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [18],    # Example TBF
    'K%': [0.2286]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [4 5 6]
# Predicted Strikeouts: [6. 6. 2.]
# Actual Strikeouts: [1 0 6]
# Mean Squared Error: 25.658589316591456
#
# Test Indices: [7 8 9]
# Predicted Strikeouts: [6. 6. 6.]
# Actual Strikeouts: [6 7 6]
# Mean Squared Error: 0.3331267999634899
#
# Test Indices: [10 11 12]
# Predicted Strikeouts: [1.   2.06 2.02]
# Actual Strikeouts: [1 4 5]
# Mean Squared Error: 4.212033425381758
#
# Test Indices: [13 14 15]
# Predicted Strikeouts: [5.03 5.68 1.92]
# Actual Strikeouts: [5 6 3]
# Mean Squared Error: 0.4196782302188969
#
# Test Indices: [16 17 18]
# Predicted Strikeouts: [4.25 5.68 1.71]
# Actual Strikeouts: [3 6 2]
# Mean Squared Error: 0.5835046524436743
#
# Average Mean Squared Error across all folds: 6.241386484919856
# Predicted Strikeouts for Next Game: 4.336396217346191

# %% [markdown]
# #TAJ BRADLEY

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [24, 20, 27, 19, 22, 19, 27, 26, 22, 22, 24, 27, 23, 21, 20, 26, 24, 24, 25, 17, 27, 26, 21],
    'K%': [0.292, 0.3, 0.37, 0.316, 0.136, 0.368, 0.407, 0.115, 0.364, 0.5, 0.208, 0.296, 0.217, 0.333, 0.3, 0.115, 0.25, 0.083, 0.2, 0.118, 0.37, 0.231, 0.286],
    'STRIKEOUT': [7, 6, 10, 6, 3, 7, 11, 3, 8, 11, 5, 8, 5, 7, 6, 3, 6, 2, 5, 2, 10, 6, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.241]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 8  9 10]
# Predicted Strikeouts: [7.   7.18 3.  ]
# Actual Strikeouts: [ 8 11  5]
# Mean Squared Error: 6.524338930067718
#
# Test Indices: [11 12 13]
# Predicted Strikeouts: [6.97 5.   6.  ]
# Actual Strikeouts: [8 5 7]
# Mean Squared Error: 0.6871970495705378
#
# Test Indices: [14 15 16]
# Predicted Strikeouts: [6. 3. 5.]
# Actual Strikeouts: [6 3 6]
# Mean Squared Error: 0.3333065358779095
#
# Test Indices: [17 18 19]
# Predicted Strikeouts: [3. 3. 3.]
# Actual Strikeouts: [2 5 2]
# Mean Squared Error: 2.0000002082399533
#
# Test Indices: [20 21 22]
# Predicted Strikeouts: [10.    5.    5.99]
# Actual Strikeouts: [10  6  6]
# Mean Squared Error: 0.3332680733004357
#
# Average Mean Squared Error across all folds: 1.975622159411311
# Predicted Strikeouts for Next Game: 5.999974250793457

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [24, 20, 27, 19, 22, 19, 27, 26, 22, 22, 24, 27, 23, 21, 20, 26, 24, 24, 25, 17, 27, 26, 21],
    'K%': [0.292, 0.3, 0.37, 0.316, 0.136, 0.368, 0.407, 0.115, 0.364, 0.5, 0.208, 0.296, 0.217, 0.333, 0.3, 0.115, 0.25, 0.083, 0.2, 0.118, 0.37, 0.231, 0.286],
    'STRIKEOUT': [7, 6, 10, 6, 3, 7, 11, 3, 8, 11, 5, 8, 5, 7, 6, 3, 6, 2, 5, 2, 10, 6, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22.29],    # Example TBF
    'K%': [0.253]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 8  9 10]
# Predicted Strikeouts: [7.   7.18 3.  ]
# Actual Strikeouts: [ 8 11  5]
# Mean Squared Error: 6.524338930067718
#
# Test Indices: [11 12 13]
# Predicted Strikeouts: [6.97 5.   6.  ]
# Actual Strikeouts: [8 5 7]
# Mean Squared Error: 0.6871970495705378
#
# Test Indices: [14 15 16]
# Predicted Strikeouts: [6. 3. 5.]
# Actual Strikeouts: [6 3 6]
# Mean Squared Error: 0.3333065358779095
#
# Test Indices: [17 18 19]
# Predicted Strikeouts: [3. 3. 3.]
# Actual Strikeouts: [2 5 2]
# Mean Squared Error: 2.0000002082399533
#
# Test Indices: [20 21 22]
# Predicted Strikeouts: [10.    5.    5.99]
# Actual Strikeouts: [10  6  6]
# Mean Squared Error: 0.3332680733004357
#
# Average Mean Squared Error across all folds: 1.975622159411311
# Predicted Strikeouts for Next Game: 5.999974250793457

# %% [markdown]
# #PABLO LOPEZ

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    "TBF": [24, 24, 21, 20, 17, 20, 23, 25, 28, 24, 23, 28, 23, 20, 20, 27, 22, 24, 21, 25, 28, 23, 22, 26, 26, 26, 27, 28, 30, 28],
    "K%": [0.292, 0.083, 0.333, 0.35, 0.353, 0.4, 0.348, 0.4, 0.107, 0.208, 0.261, 0.214, 0.174, 0.25, 0.15, 0.519, 0.409, 0.25, 0.238, 0.28, 0.25, 0.304, 0.091, 0.192, 0.115, 0.346, 0.111, 0.321, 0.333, 0.143],
    "STRIKEOUT": [7, 2, 7, 7, 6, 8, 8, 10, 3, 5, 6, 6, 4, 5, 3, 14, 9, 6, 5, 7, 7, 7, 2, 5, 3, 9, 3, 9, 10, 4]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [27],    # Example TBF
    'K%': [0.2508]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6 7 8 9]
# Predicted Strikeouts: [7. 7. 7. 2. 2.]
# Actual Strikeouts: [ 8  8 10  3  5]
# Mean Squared Error: 4.1994394809072215
#
# Test Indices: [10 11 12 13 14]
# Predicted Strikeouts: [5.07 5.01 2.67 5.   2.67]
# Actual Strikeouts: [6 6 4 5 3]
# Mean Squared Error: 0.7468968460108159
#
# Test Indices: [15 16 17 18 19]
# Predicted Strikeouts: [10.    8.02  5.11  5.11  7.61]
# Actual Strikeouts: [14  9  6  5  7]
# Mean Squared Error: 3.6291376689629486
#
# Test Indices: [20 21 22 23 24]
# Predicted Strikeouts: [6.25 7.02 2.   4.13 3.  ]
# Actual Strikeouts: [7 7 2 5 3]
# Mean Squared Error: 0.26516662711280786
#
# Test Indices: [25 26 27 28 29]
# Predicted Strikeouts: [7.67 3.   7.17 7.68 3.  ]
# Actual Strikeouts: [ 9  3  9 10  4]
# Mean Squared Error: 2.295740903749322
#
# Average Mean Squared Error across all folds: 2.227276305348623
# Predicted Strikeouts for Next Game: 6.9702839851379395

# %% [markdown]
# #KUTTER CRAWFORD

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 20, 22, 19, 27, 28, 27, 24, 26, 24, 22, 25, 25, 26, 21, 27, 6, 21, 23, 26, 22, 23, 23, 20, 20, 20, 20, 28, 20, 27, 21],
    'K%': [0.318, 0.25, 0.273, 0.316, 0.222, 0.143, 0.222, 0.25, 0.231, 0.208, 0.182, 0.2, 0.2, 0.308, 0.429, 0.259, 0.333, 0.333, 0.174, 0.154, 0.091, 0.217, 0.217, 0.15, 0.2, 0.2, 0.15, 0.107, 0.4, 0.222, 0.333],
    'STRIKEOUT': [7, 5, 6, 6, 6, 4, 6, 6, 6, 5, 4, 5, 5, 8, 9, 7, 2, 7, 4, 4, 2, 5, 5, 3, 4, 4, 3, 3, 8, 6, 7]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.2424]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 6  7  8  9 10]
# Predicted Strikeouts: [6.   5.98 5.98 5.98 5.98]
# Actual Strikeouts: [6 6 6 5 4]
# Mean Squared Error: 0.9716806807617558
#
# Test Indices: [11 12 13 14 15]
# Predicted Strikeouts: [4.   4.   6.   6.49 6.  ]
# Actual Strikeouts: [5 5 8 9 7]
# Mean Squared Error: 2.655285224350746
#
# Test Indices: [16 17 18 19 20]
# Predicted Strikeouts: [5.93 7.   4.   4.03 4.  ]
# Actual Strikeouts: [2 7 4 4 2]
# Mean Squared Error: 3.8904983144948346
#
# Test Indices: [21 22 23 24 25]
# Predicted Strikeouts: [4.99 4.99 3.98 4.96 4.96]
# Actual Strikeouts: [5 5 3 4 4]
# Mean Squared Error: 0.5639080085665682
#
# Test Indices: [26 27 28 29 30]
# Predicted Strikeouts: [3.   2.89 7.01 6.   7.  ]
# Actual Strikeouts: [3 3 8 6 7]
# Mean Squared Error: 0.1998287832284973
#
# Average Mean Squared Error across all folds: 1.6562402022804803
# Predicted Strikeouts for Next Game: 5.990877628326416

# %% [markdown]
# #BRADY SINGER

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 20, 22, 19, 27, 28, 27, 24, 26, 24, 22, 25, 25, 26, 21, 27, 6, 21, 23, 26, 22, 23, 23, 20, 20, 20, 20, 28, 20, 27, 21],
    'K%': [0.318, 0.25, 0.273, 0.316, 0.222, 0.143, 0.222, 0.25, 0.231, 0.208, 0.182, 0.2, 0.2, 0.308, 0.429, 0.259, 0.333, 0.333, 0.174, 0.154, 0.091, 0.217, 0.217, 0.15, 0.2, 0.2, 0.15, 0.107, 0.4, 0.222, 0.333],
    'STRIKEOUT': [7, 5, 6, 6, 6, 4, 6, 6, 6, 5, 4, 5, 5, 8, 9, 7, 2, 7, 4, 4, 2, 5, 5, 3, 4, 4, 3, 3, 8, 6, 7]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.2424]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 6  7  8  9 10]
# Predicted Strikeouts: [6.   5.98 5.98 5.98 5.98]
# Actual Strikeouts: [6 6 6 5 4]
# Mean Squared Error: 0.9716806807617558
#
# Test Indices: [11 12 13 14 15]
# Predicted Strikeouts: [4.   4.   6.   6.49 6.  ]
# Actual Strikeouts: [5 5 8 9 7]
# Mean Squared Error: 2.655285224350746
#
# Test Indices: [16 17 18 19 20]
# Predicted Strikeouts: [5.93 7.   4.   4.03 4.  ]
# Actual Strikeouts: [2 7 4 4 2]
# Mean Squared Error: 3.8904983144948346
#
# Test Indices: [21 22 23 24 25]
# Predicted Strikeouts: [4.99 4.99 3.98 4.96 4.96]
# Actual Strikeouts: [5 5 3 4 4]
# Mean Squared Error: 0.5639080085665682
#
# Test Indices: [26 27 28 29 30]
# Predicted Strikeouts: [3.   2.89 7.01 6.   7.  ]
# Actual Strikeouts: [3 3 8 6 7]
# Mean Squared Error: 0.1998287832284973
#
# Average Mean Squared Error across all folds: 1.6562402022804803
# Predicted Strikeouts for Next Game: 5.990877628326416

# %% [markdown]
# #BRADY SINGER

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [27, 21, 22, 20, 26, 23, 22, 22, 25, 26, 22, 21, 27, 24, 21, 27, 20, 27, 16, 27, 24, 27, 27, 25, 23, 25, 24, 24, 22, 25],
    'K%': [0.37, 0.19, 0.182, 0.25, 0.192, 0.261, 0.364, 0.182, 0.24, 0.346, 0.136, 0.095, 0.222, 0.167, 0.19, 0.185, 0.2, 0.259, 0.188, 0.259, 0.208, 0.148, 0.222, 0.36, 0.261, 0.2, 0.25, 0.125, 0.136, 0.24],
    'STRIKEOUT': [10, 4, 4, 5, 5, 6, 8, 4, 6, 9, 3, 2, 6, 4, 4, 5, 4, 7, 3, 7, 5, 4, 6, 9, 6, 5, 6, 3, 3, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [24],    # Example TBF
    'K%': [0.1902]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6 7 8 9]
# Predicted Strikeouts: [5. 5. 4. 5. 5.]
# Actual Strikeouts: [6 8 4 6 9]
# Mean Squared Error: 5.400123667961452
#
# Test Indices: [10 11 12 13 14]
# Predicted Strikeouts: [4.   4.   5.83 4.81 4.  ]
# Actual Strikeouts: [3 2 6 4 4]
# Mean Squared Error: 1.1384880183288715
#
# Test Indices: [15 16 17 18 19]
# Predicted Strikeouts: [4.08 4.9  6.   3.99 6.  ]
# Actual Strikeouts: [5 4 7 3 7]
# Mean Squared Error: 0.9259277619215937
#
# Test Indices: [20 21 22 23 24]
# Predicted Strikeouts: [4.02 4.12 6.   9.   6.  ]
# Actual Strikeouts: [5 4 6 9 6]
# Mean Squared Error: 0.19463525862001915
#
# Test Indices: [25 26 27 28 29]
# Predicted Strikeouts: [5.16 5.42 2.62 3.   6.  ]
# Actual Strikeouts: [5 6 3 3 6]
# Mean Squared Error: 0.10234950690397682
#
# Average Mean Squared Error across all folds: 1.5523048427471828
# Predicted Strikeouts for Next Game: 4.347435474395752

# %% [markdown]
# #AARON CIVALE

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 23, 21, 23, 27, 22, 21, 20, 20, 25, 20, 23, 24, 24, 20, 18, 25, 23, 28, 21, 22, 20, 24, 24, 20, 25, 21, 20, 20],
    'K%': [0.273, 0.348, 0.19, 0.348, 0.185, 0.136, 0.238, 0.2, 0.3, 0.12, 0.25, 0.13, 0.333, 0.25, 0.25, 0.167, 0.08, 0.348, 0.214, 0.19, 0.136, 0.15, 0.208, 0.167, 0.15, 0.28, 0.333, 0.1, 0.3],
    'STRIKEOUT': [6, 8, 4, 8, 5, 3, 5, 4, 6, 3, 5, 3, 8, 6, 5, 3, 2, 8, 6, 4, 3, 3, 5, 4, 3, 7, 7, 2, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [21],    # Example TBF
    'K%': [0.2326]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 9 10 11 12]
# Predicted Strikeouts: [3.78 5.   3.78 8.  ]
# Actual Strikeouts: [3 5 3 8]
# Mean Squared Error: 0.30439467028921285
#
# Test Indices: [13 14 15 16]
# Predicted Strikeouts: [5. 5. 3. 3.]
# Actual Strikeouts: [6 5 3 2]
# Mean Squared Error: 0.5001341317432093
#
# Test Indices: [17 18 19 20]
# Predicted Strikeouts: [8. 5. 4. 3.]
# Actual Strikeouts: [8 6 4 3]
# Mean Squared Error: 0.24998308425638527
#
# Test Indices: [21 22 23 24]
# Predicted Strikeouts: [3.   4.44 3.   3.  ]
# Actual Strikeouts: [3 5 4 3]
# Mean Squared Error: 0.3295960462815515
#
# Test Indices: [25 26 27 28]
# Predicted Strikeouts: [6.01 7.99 2.   6.  ]
# Actual Strikeouts: [7 7 2 6]
# Mean Squared Error: 0.49430149952492286
#
# Average Mean Squared Error across all folds: 0.37568188641905637
# Predicted Strikeouts for Next Game: 5.000030517578125

# %% [markdown]
# #RONEL BLANCO

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    "TBF": [29, 23, 24, 26, 26, 24, 24, 14, 25, 20, 24, 22, 25, 27, 26, 22, 25, 22, 24, 20, 23, 19, 20, 21, 25, 21, 23],
    "K%": [0.241, 0.174, 0.208, 0.231, 0.308, 0.25, 0.208, 0.286, 0.24, 0.3, 0.083, 0.364, 0.32, 0.148, 0.192, 0.182,
           0.28, 0.227, 0.208, 0.45, 0.304, 0.263, 0.2, 0.286, 0.2, 0.143, 0.217],
    "STRIKEOUT": [7, 4, 5, 6, 8, 6, 5, 4, 6, 6, 2, 8, 8, 4, 5, 4, 7, 5, 5, 9, 7, 5, 4, 6, 5, 3, 5]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22],    # Example TBF
    'K%': [0.2092]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 7  8  9 10]
# Predicted Strikeouts: [5.78 6.   5.78 5.  ]
# Actual Strikeouts: [4 6 6 2]
# Mean Squared Error: 3.0513474266633693
#
# Test Indices: [11 12 13 14]
# Predicted Strikeouts: [6.82 8.   3.93 3.93]
# Actual Strikeouts: [8 8 4 5]
# Mean Squared Error: 0.6329939846689854
#
# Test Indices: [15 16 17 18]
# Predicted Strikeouts: [4.  6.1 5.  5. ]
# Actual Strikeouts: [4 7 5 5]
# Mean Squared Error: 0.20350627220312845
#
# Test Indices: [19 20 21 22]
# Predicted Strikeouts: [7.7  6.21 4.   5.  ]
# Actual Strikeouts: [9 7 5 4]
# Mean Squared Error: 1.0777326626526929
#
# Test Indices: [23 24 25 26]
# Predicted Strikeouts: [5.46 5.06 2.   4.9 ]
# Actual Strikeouts: [6 5 3 5]
# Mean Squared Error: 0.32658652168953495
#
# Average Mean Squared Error across all folds: 1.0584333735755422
# Predicted Strikeouts for Next Game: 4.999897003173828

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    "TBF": [29, 23, 24, 26, 26, 24, 24, 14, 25, 20, 24, 22, 25, 27, 26, 22, 25, 22, 24, 20, 23, 19, 20, 21, 25, 21, 23],
    "K%": [0.241, 0.174, 0.208, 0.231, 0.308, 0.25, 0.208, 0.286, 0.24, 0.3, 0.083, 0.364, 0.32, 0.148, 0.192, 0.182,
           0.28, 0.227, 0.208, 0.45, 0.304, 0.263, 0.2, 0.286, 0.2, 0.143, 0.217],
    "STRIKEOUT": [7, 4, 5, 6, 8, 6, 5, 4, 6, 6, 2, 8, 8, 4, 5, 4, 7, 5, 5, 9, 7, 5, 4, 6, 5, 3, 5]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22],    # Example TBF
    'K%': [0.2344]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 7  8  9 10]
# Predicted Strikeouts: [5.78 6.   5.78 5.  ]
# Actual Strikeouts: [4 6 6 2]
# Mean Squared Error: 3.0513474266633693
#
# Test Indices: [11 12 13 14]
# Predicted Strikeouts: [6.82 8.   3.93 3.93]
# Actual Strikeouts: [8 8 4 5]
# Mean Squared Error: 0.6329939846689854
#
# Test Indices: [15 16 17 18]
# Predicted Strikeouts: [4.  6.1 5.  5. ]
# Actual Strikeouts: [4 7 5 5]
# Mean Squared Error: 0.20350627220312845
#
# Test Indices: [19 20 21 22]
# Predicted Strikeouts: [7.7  6.21 4.   5.  ]
# Actual Strikeouts: [9 7 5 4]
# Mean Squared Error: 1.0777326626526929
#
# Test Indices: [23 24 25 26]
# Predicted Strikeouts: [5.46 5.06 2.   4.9 ]
# Actual Strikeouts: [6 5 3 5]
# Mean Squared Error: 0.32658652168953495
#
# Average Mean Squared Error across all folds: 1.0584333735755422
# Predicted Strikeouts for Next Game: 5.921739101409912

# %% [markdown]
# #CHRIS FLEXEN

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 25, 16, 20, 20, 21, 22, 21, 21, 23, 18, 18, 20, 25, 27, 26, 23, 25, 24, 23, 26, 15, 19, 19, 26, 20, 22, 22],
    'K%': [0.045, 0.16, 0.125, 0.1, 0.2, 0.381, 0.227, 0.19, 0.095, 0.261, 0.222, 0.167, 0.1, 0.24, 0.111, 0.115, 0.174, 0.16, 0.167, 0.13, 0.077, 0.2, 0.053, 0.053, 0.192, 0.25, 0.273, 0.364],
    'STRIKEOUT': [1, 4, 2, 2, 4, 8, 5, 4, 2, 6, 4, 3, 2, 6, 3, 3, 4, 4, 4, 3, 2, 3, 1, 1, 5, 5, 6, 8]
}


# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22],    # Example TBF
    'K%': [0.2264]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 8  9 10 11]
# Predicted Strikeouts: [1. 5. 4. 4.]
# Actual Strikeouts: [2 6 4 3]
# Mean Squared Error: 0.7494461104415251
#
# Test Indices: [12 13 14 15]
# Predicted Strikeouts: [2.   4.96 2.13 2.13]
# Actual Strikeouts: [2 6 3 3]
# Mean Squared Error: 0.6520831184048781
#
# Test Indices: [16 17 18 19]
# Predicted Strikeouts: [4.   4.   4.   3.14]
# Actual Strikeouts: [4 4 4 3]
# Mean Squared Error: 0.005209625864324607
#
# Test Indices: [20 21 22 23]
# Predicted Strikeouts: [1.85 3.9  1.18 1.18]
# Actual Strikeouts: [2 3 1 1]
# Mean Squared Error: 0.22474582927805997
#
# Test Indices: [24 25 26 27]
# Predicted Strikeouts: [4.01 6.72 6.04 6.04]
# Actual Strikeouts: [5 5 6 8]
# Mean Squared Error: 1.9461288833597337
#
# Average Mean Squared Error across all folds: 0.7155227134697043
# Predicted Strikeouts for Next Game: 4.09274435043335

# %% [markdown]
# #CAL QUANTRIL

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    "TBF": [24, 19, 25, 23, 27, 24, 26, 24, 23, 22, 22, 22, 21, 23, 26, 25, 24, 22, 12, 26, 24, 24, 21, 22, 19, 27, 17],
    "K%": [0.042, 0.158, 0.24, 0.043, 0.148, 0.083, 0.346, 0.208, 0.217, 0.364, 0.227, 0.045, 0.048, 0.217, 0.115, 0.2, 0.333, 0.091, 0.333, 0.192, 0.125, 0.167, 0.095, 0.227, 0.211, 0.074, 0.118],
    "STRIKEOUT": [1, 3, 6, 1, 4, 2, 9, 5, 5, 8, 5, 1, 1, 5, 3, 5, 8, 2, 4, 5, 3, 4, 2, 5, 4, 2, 2]
}


# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [21],    # Example TBF
    'K%': [0.145]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 7  8  9 10]
# Predicted Strikeouts: [3.04 3.04 6.   3.  ]
# Actual Strikeouts: [5 5 8 5]
# Mean Squared Error: 3.9259788714904715
#
# Test Indices: [11 12 13 14]
# Predicted Strikeouts: [1.   1.   5.   2.97]
# Actual Strikeouts: [1 1 5 3]
# Mean Squared Error: 0.00020182500497867295
#
# Test Indices: [15 16 17 18]
# Predicted Strikeouts: [3.13 5.96 2.   5.91]
# Actual Strikeouts: [5 8 2 4]
# Mean Squared Error: 2.834304855169833
#
# Test Indices: [19 20 21 22]
# Predicted Strikeouts: [3.01 2.99 3.   2.  ]
# Actual Strikeouts: [5 3 4 2]
# Mean Squared Error: 1.238372551136539
#
# Test Indices: [23 24 25 26]
# Predicted Strikeouts: [5.   4.98 1.01 2.91]
# Actual Strikeouts: [5 4 2 2]
# Mean Squared Error: 0.6906786600839503
#
# Average Mean Squared Error across all folds: 1.7379073525771545
# Predicted Strikeouts for Next Game: 2.9604451656341553
