# %% [markdown]
# <a href="https://colab.research.google.com/github/starlingomez/preworkmac/blob/master/AUGUST2ND.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #JOY ESTES

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    "IP": [3.2, 7, 5, 6.1, 5, 2.2, 6, 5.2, 9, 1.2, 6, 5.2],
    "TBF": [23, 27, 20, 20, 24, 18, 24, 23, 30, 14, 24, 26],
    "K/9": [9.8, 7.7, 9, 7.1, 5.4, 6.7, 1.5, 12.7, 4, 5.4, 7.5, 6.4],
    "K%": [0.174, 0.222, 0.25, 0.25, 0.125, 0.111, 0.042, 0.348, 0.133, 0.071, 0.208, 0.154],
    "VSK/9": [12, 10.5, 3.6, 6, 17.2, 14.4, 7.2, 14.2, 18.7, 12, 13.5, 9.5],
    "VSK%": [0.381, 0.292, 0.091, 0.174, 0.368, 0.421, 0.154, 0.4, 0.45, 0.333, 0.333, 0.273],
    "SO": [4, 6, 5, 5, 3, 2, 1, 8, 4, 1, 5, 4]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 26.3673
# Epoch 2/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 22.3080
# Epoch 3/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 20.9251
# Epoch 4/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 26.1291
# Epoch 5/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 25.0384
# Epoch 6/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 19.5010
# Epoch 7/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.9410
# Epoch 8/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.2746
# Epoch 9/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.9504
# Epoch 10/500
# ...

# %% [markdown]
# #RANDY VASQUEZ

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    "IP": [4.1, 3.2, 6, 5, 6.2, 5, 4.1, 5, 4, 6.1, 5, 6, 2],
    "TBF": [17, 20, 26, 20, 27, 22, 24, 20, 18, 25, 19, 22, 14],
    "K/9": [12.5, 0, 3, 9, 4.1, 9, 4.2, 5.4, 2.3, 8.5, 9, 1.5, 9],
    "K%": [0.353, 0, 0.077, 0.25, 0.111, 0.227, 0.083, 0.15, 0.056, 0.24, 0.263, 0.045, 0.143],
    "VSK/9": [10.8, 6, 18, 3, 5.1, 20.2, 14.8, 22.5, 14.4, 18, 9, 9, 12],
    "VSK%": [0.3, 0.148, 0.545, 0.067, 0.16, 0.316, 0.478, 0.682, 0.4, 0.667, 0.231, 0.238, 0.348],
    "SO": [6, 0, 2, 5, 3, 5, 2, 3, 1, 6, 5, 1, 2]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 11.3287
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.9399
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0037
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9986
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.3067
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7968
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4208
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5963
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6848
# Epoch 10/500
# ...

# %% [markdown]
# #JOE RYAN

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [5.1, 7, 7, 5, 7, 7, 6, 6, 5.2, 5.2, 5.1, 6, 6],
    'TBF': [23, 25, 25, 23, 25, 25, 24, 24, 27, 24, 25, 25, 23],
    'K/9': [8.4, 7.7, 11.6, 7.2, 10.3, 6.4, 7.5, 7.5, 15.9, 12.7, 10.1, 9, 12],
    'K%': [0.217, 0.24, 0.36, 0.174, 0.32, 0.2, 0.208, 0.208, 0.37, 0.333, 0.24, 0.24, 0.348],
    'VSK/9': [9, 9, 6, 14.4, 5.9, 12.9, 13.5, 9, 6.8, 8.5, 5.8, 6.4, 5.1],
    'VSK%': [0.292, 0.259, 0.2, 0.364, 0.185, 0.4, 0.429, 0.259, 0.167, 0.24, 0.143, 0.185, 0.148],
    'SO': [5, 6, 9, 4, 8, 5, 5, 5, 10, 8, 6, 6, 8]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 36.3135
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.1901
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 40.4361
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 32.0216
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.9429
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.3838
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.7401
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.9856
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.1616
# Epoch 10/500
# ...

# %% [markdown]
# #COLE RAGAN

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    "IP": [7, 6, 5, 6, 6, 7, 6, 6, 4.2, 7, 7, 6, 5.2],
    "TBF": [23, 23, 24, 24, 22, 26, 26, 25, 21, 28, 25, 26, 26],
    "K/9": [9, 18, 12.6, 9, 13.5, 5.1, 10.5, 16.5, 11.6, 10.3, 9, 7.5, 11.1],
    "K%": [0.304, 0.522, 0.292, 0.25, 0.409, 0.154, 0.269, 0.44, 0.286, 0.286, 0.28, 0.192, 0.269],
    "VSK/9": [8.1, 14.4, 6.8, 10.1, 2.1, 7.2, 13.5, 9, 12, 12.4, 3, 14.4, 3.4],
    "VSK%": [0.214, 0.348, 0.185, 0.25, 0.056, 0.235, 0.36, 0.25, 0.348, 0.407, 0.083, 0.421, 0.107],
    "SO": [7, 12, 7, 6, 9, 4, 7, 11, 6, 8, 7, 5, 7]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 72.2945
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 56.6960
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 69.7503
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 57.1410
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 61.6985
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 59.5959
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 47.5066
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 43.2842
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 48.2963
# Epoch 10/500
# ...

# %% [markdown]
# #TYLER ANDERSON

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [7, 8, 5, 6.2, 6, 5.1, 7, 5, 4.2, 8, 6, 5.2, 7],
    'TBF': [25, 31, 23, 26, 26, 25, 27, 25, 22, 27, 24, 22, 27],
    'K/9': [5.1, 4.5, 7.2, 2.7, 4.5, 8.4, 6.4, 3.6, 3.9, 11.3, 6, 12.7, 12.9],
    'K%': [0.16, 0.129, 0.174, 0.077, 0.115, 0.2, 0.185, 0.08, 0.091, 0.37, 0.167, 0.364, 0.37],
    'VSK/9': [1.9, 9, 9.6, 7.2, 10.8, 6.4, 11, 6.7, 14.1, 6, 5.4, 10.8, 10.5],
    'VSK%': [0.045, 0.238, 0.227, 0.148, 0.286, 0.148, 0.375, 0.118, 0.478, 0.167, 0.1, 0.316, 0.304],
    'SO': [4, 4, 4, 2, 3, 5, 5, 2, 2, 10, 4, 8, 10]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.9572
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.3150
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.7198
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.2896
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.9044
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.5070
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.5907
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.0821
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.1493
# Epoch 10/500
# ...

# %% [markdown]
# #ANDREW ABBOTT

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [7, 7, 6, 6, 5, 5, 5.2, 5, 6.1, 7, 3.1, 6.2, 4],
    'TBF': [26, 25, 27, 26, 24, 22, 22, 23, 26, 25, 19, 28, 21],
    'K/9': [5.1, 2.6, 4.5, 9, 9, 5.4, 15.9, 3.6, 2.8, 10.3, 10.8, 1.4, 4.5],
    'K%': [0.154, 0.08, 0.111, 0.231, 0.208, 0.136, 0.455, 0.087, 0.077, 0.32, 0.211, 0.036, 0.095],
    'VSK/9': [7.5, 6, 7.7, 3.4, 10.8, 7.2, 13.5, 18, 9, 7.5, 14.7, 11.6, 0],
    'VSK%': [0.192, 0.167, 0.231, 0.091, 0.3, 0.19, 0.3, 0.381, 0.231, 0.2, 0.333, 0.391, 0],
    'SO': [4, 2, 3, 6, 5, 3, 10, 2, 2, 8, 4, 1, 2]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 22.2658
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.2789
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 25.2666
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.0500
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.1530
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.1393
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.5863
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.9696
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.7821
# Epoch 10/500
# ...

# %% [markdown]
# #YUSEI KIKUCHI

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [3, 5.1, 6, 5, 4, 2, 5, 5.2, 7.1, 4.2, 5, 4.2],
    'TBF': [17, 25, 22, 22, 18, 15, 20, 24, 27, 24, 23, 24],
    'K/9': [0, 6.8, 9, 9, 15.8, 13.5, 12.6, 7.9, 16, 11.6, 14.4, 9.6],
    'K%': [0, 0.16, 0.273, 0.227, 0.389, 0.2, 0.35, 0.208, 0.481, 0.25, 0.348, 0.208],
    'VSK/9': [12, 2.1, 8.4, 12.9, 9.6, 9.5, 10.8, 6.8, 4.5, 6.4, 12.6, 12.6],
    'VSK%': [0.32, 0.045, 0.25, 0.4, 0.227, 0.3, 0.261, 0.185, 0.095, 0.192, 0.35, 0.368],
    'SO': [0, 4, 6, 5, 7, 3, 7, 5, 13, 6, 8, 5]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 30.8705
# Epoch 2/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.7349
# Epoch 3/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.1420
# Epoch 4/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.0431
# Epoch 5/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.4148
# Epoch 6/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.8143
# Epoch 7/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.5475
# Epoch 8/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.1533
# Epoch 9/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.3059
# Epoch 10/500
# ...

# %% [markdown]
# #KUTTER CRAWFORD

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [5.2, 4.1, 6, 6, 6, 6, 6.1, 1.1, 6, 7, 7, 5, 4.2],
    'TBF': [24, 22, 25, 25, 21, 21, 27, 6, 21, 23, 26, 22, 23],
    'K/9': [7.9, 8.3, 7.5, 7.5, 13.5, 13.5, 9.9, 13.5, 10.5, 5.1, 5.1, 3.6, 9.6],
    'K%': [0.208, 0.182, 0.2, 0.2, 0.429, 0.429, 0.259, 0.333, 0.333, 0.174, 0.154, 0.091, 0.217],
    'VSK/9': [9, 12, 3.4, 7.1, 15.8, 15.8, 5.8, 1.5, 9.6, 8, 6.4, 9, 5.4],
    'VSK%': [0.25, 0.348, 0.083, 0.208, 0.389, 0.389, 0.13, 0.04, 0.208, 0.235, 0.179, 0.208, 0.111],
    'SO': [5, 4, 5, 5, 8, 8, 9, 2, 7, 4, 4, 2, 5]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 29.5573
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.3311
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.6670
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.0627
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 27.1190
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.7252
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.5907
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.5103
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.0427
# Epoch 10/500
# ...

# %% [markdown]
# #GAVIN STONE

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [6, 6, 7, 5, 5.2, 7, 5.1, 9, 3, 4.2, 5, 6],
    'TBF': [25, 26, 24, 20, 27, 26, 23, 30, 19, 21, 21, 29],
    'K/9': [3, 7.5, 9, 10.8, 9.5, 3.9, 11.8, 7, 9, 5.8, 5.4, 4.5],
    'K%': [0.08, 0.192, 0.292, 0.3, 0.222, 0.115, 0.304, 0.233, 0.158, 0.143, 0.143, 0.103],
    'VSK/9': [8.1, 9, 5.8, 4.5, 11.3, 12, 2.7, 4.8, 12.9, 6.7, 8.3, 6],
    'VSK%': [0.167, 0.211, 0.15, 0.115, 0.263, 0.308, 0.063, 0.143, 0.37, 0.133, 0.19, 0.176],
    'SO': [2, 5, 7, 6, 6, 3, 7, 7, 3, 3, 3, 3]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 29.0141
# Epoch 2/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 30.9277
# Epoch 3/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.6869
# Epoch 4/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 28.3917
# Epoch 5/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.5434
# Epoch 6/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 30.4072
# Epoch 7/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 26.9540
# Epoch 8/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 25.5152
# Epoch 9/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 26.7118
# Epoch 10/500
# ...

# %% [markdown]
# #KEVIN GAUSMAN

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    "IP": [6, 6, 6.1, 9, 5.1, 5.2, 6, 4.1, 6, 7, 6.2, 9],
    "TBF": [21, 22, 27, 32, 23, 27, 26, 26, 27, 27, 27, 34],
    "K/9": [15, 4.5, 4.3, 10, 10.1, 6.4, 7.5, 14.5, 15, 3.9, 6.8, 8],
    "K%": [0.476, 0.136, 0.111, 0.313, 0.261, 0.148, 0.192, 0.269, 0.37, 0.111, 0.185, 0.235],
    "VSK/9": [11.1, 6.4, 10.8, 3, 9.6, 7.2, 7.7, 10.8, 9.5, 2.7, 6.4, 9],
    "VSK%": [0.28, 0.148, 0.261, 0.077, 0.217, 0.19, 0.182, 0.273, 0.231, 0.056, 0.217, 0.192],
    "SO": [10, 3, 3, 10, 6, 4, 5, 7, 10, 3, 5, 8]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 40.5653
# Epoch 2/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.9089
# Epoch 3/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 39.0669
# Epoch 4/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 38.9821
# Epoch 5/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 35.4781
# Epoch 6/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.1253
# Epoch 7/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 35.1971
# Epoch 8/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 29.1005
# Epoch 9/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.5012
# Epoch 10/500
# ...

# %% [markdown]
# #DEAN KREMER

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [7, 4, 5.2, 5.1, 7, 6, 5.2, 4, 5, 4, 4.2, 5.1, 6],
    'TBF': [26, 24, 22, 20, 26, 20, 26, 21, 19, 24, 21, 24, 27],
    'K/9': [7.7, 6.8, 4.8, 16.9, 5.1, 9, 15.9, 4.5, 14.4, 6.8, 7.7, 3.4, 10.5],
    'K%': [0.231, 0.125, 0.136, 0.5, 0.154, 0.3, 0.385, 0.095, 0.421, 0.125, 0.19, 0.083, 0.259],
    'VSK/9': [7.5, 12.9, 7.7, 7.7, 10.8, 9, 9, 3, 4, 2.3, 13.5, 3.4, 6.2],
    'VSK%': [0.217, 0.455, 0.261, 0.194, 0.286, 0.261, 0.25, 0.069, 0.138, 0.059, 0.143, 0.1, 0.136],
    'SO': [6, 3, 3, 10, 4, 6, 10, 2, 8, 3, 4, 2, 7]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 36.0320
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.8255
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 26.0984
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.5995
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.1138
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.1602
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.4814
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 25.2718
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 26.3404
# Epoch 10/500
# ...

# %% [markdown]
# #JAVIER ASSAD

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [6, 4.1, 6, 4.2, 5, 5.1, 5.2, 4.2, 5, 4.1, 2.1, 3.1, 6],
    'TBF': [25, 20, 23, 24, 23, 22, 27, 22, 22, 20, 15, 17, 24],
    'K/9': [6, 8.3, 10.5, 7.7, 14.4, 11.8, 11.1, 7.7, 12.6, 0, 0, 5.4, 7.5],
    'K%': [0.16, 0.2, 0.304, 0.167, 0.348, 0.318, 0.259, 0.182, 0.318, 0, 0, 0.118, 0.208],
    'VSK/9': [6, 16.2, 12, 3.9, 8.6, 3, 5.4, 8.4, 14.4, 3, 11.3, 4.2, 9.5],
    'VSK%': [0.174, 0.375, 0.32, 0.107, 0.276, 0.08, 0.12, 0.238, 0.421, 0.08, 0.294, 0.095, 0.233],
    'SO': [4, 4, 7, 4, 8, 7, 7, 4, 7, 0, 0, 2, 5]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 31.9182
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.8593
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.9200
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.8927
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.3559
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.9635
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.7525
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.8575
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.6460
# Epoch 10/500
# ...

# %% [markdown]
# BRANDON PFAADT

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [6, 7, 6, 5.1, 6, 6.1, 6.1, 6, 4.1, 6, 7, 6],
    'TBF': [23, 28, 24, 26, 26, 25, 26, 25, 19, 20, 23, 24],
    'K/9': [10.5, 6.4, 12, 8.4, 12, 0, 2.8, 12, 12.5, 6, 9, 6],
    'K%': [0.304, 0.179, 0.333, 0.192, 0.308, 0, 0.077, 0.32, 0.316, 0.2, 0.304, 0.167],
    'VSK/9': [7.2, 3.2, 4.5, 4.5, 3.6, 9, 9, 6, 12.6, 12, 12.7, 15],
    'VSK%': [0.182, 0.087, 0.136, 0.13, 0.091, 0.176, 0.222, 0.167, 0.368, 0.444, 0.296, 0.4],
    'SO': [7, 5, 8, 5, 8, 0, 2, 8, 6, 4, 7, 4]
}


df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 34.9137
# Epoch 2/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.2004
# Epoch 3/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 32.2439
# Epoch 4/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.9460
# Epoch 5/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.3319
# Epoch 6/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.9970
# Epoch 7/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.3904
# Epoch 8/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.8310
# Epoch 9/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.6175
# Epoch 10/500
# ...

# %% [markdown]
# #AUSTIN GOMBER

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [8, 3, 5, 3, 6.2, 5.1, 6, 7.0, 5.0, 5.2, 3.2],
    'TBF': [28, 17, 22, 19, 26, 24, 24, 27.0, 23.0, 24.0, 18.0],
    'K/9': [6.8, 6.0, 7.2, 6.0, 4.1, 6.8, 4.5, 3.9, 9.0, 7.9, 14.7],
    'K%': [0.214, 0.118, 0.182, 0.105, 0.115, 0.167, 0.125, 0.111, 0.217, 0.208, 0.333],
    'VSK/9': [4.8, 12.3, 3.4, 7.2, 15.0, 9.0, 3.6, 10.5, 3.9, 10.3, 0.0],
    'VSK%': [0.143, 0.238, 0.087, 0.190, 0.263, 0.259, 0.100, 0.259, 0.100, 0.296, 0.0],
    'SO': [6, 2, 4, 2, 3, 4, 3, 3, 5, 5, 6]
}

df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "K/9", "K%", "VSK/9", "VSK%"]]
y = df['SO'].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 7.3767
# Epoch 2/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8047
# Epoch 3/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7011
# Epoch 4/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0329
# Epoch 5/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5802
# Epoch 6/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0080
# Epoch 7/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8065
# Epoch 8/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3000
# Epoch 9/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0503
# Epoch 10/500
# ...
