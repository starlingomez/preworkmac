# %% [markdown]
# <a href="https://colab.research.google.com/github/starlingomez/preworkmac/blob/master/AGOSTO4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #RYEN NELSON

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [6, 7.2, 3.1, 6, 7, 3.2, 5, 6.2, 7, 5.2, 6, 7],
    'SPK/9': [4.5, 1.2, 2.7, 12, 2.6, 7.4, 5.4, 6.8, 6.4, 14.3, 3, 11.6],
    'SPK%': [0.12, 0.037, 0.048, 0.333, 0.083, 0.13, 0.136, 0.217, 0.192, 0.409, 0.074, 0.375],
    'SPSO': [3, 1, 1, 8, 2, 3, 3, 5, 5, 9, 2, 9],
    'TBF': [22, 23, 22, 17, 27, 24, 19, 9, 27, 25, 22, 12],
    'K/9': [4.5, 4.5, 3.6, 9, 9, 6, 12.6, 12, 12.7, 15, 5.4, 9],
    'K%': [0.136, 0.13, 0.091, 0.176, 0.222, 0.167, 0.368, 0.444, 0.296, 0.4, 0.136, 0.25],
    'SO': [3, 3, 2, 3, 6, 4, 7, 4, 8, 10, 3, 3]
}

df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "SPK/9", "SPK%", "SPSO", "TBF", "K/9", "K%"]]
y = df["SO"].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 18.5951
# Epoch 2/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 17.9956
# Epoch 3/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.7396
# Epoch 4/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 15.0894
# Epoch 5/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13.0227
# Epoch 6/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 14.0476
# Epoch 7/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 15.4759
# Epoch 8/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 13.0273
# Epoch 9/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 13.6723
# Epoch 10/500
# ...

# %% [markdown]
# #MAX FRIED

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [6, 7, 7, 4.1, 9, 8, 7, 5, 5.1, 6, 6, 6, 6],
    'SPK/9': [10.5, 9, 6.4, 4.2, 9, 6.8, 16.7, 5.4, 10.1, 6, 6, 6, 10.5],
    'SPK%': [0.35, 0.25, 0.208, 0.083, 0.3, 0.222, 0.464, 0.13, 0.261, 0.182, 0.148, 0.129, 0.28],
    'SPSO': [7, 7, 5, 2, 9, 6, 13, 3, 6, 4, 4, 4, 7],
    'TBF': [21, 23, 15, 18, 29, 27, 22, 18, 18, 20, 24, 27, 22],
    'K/9': [9, 7.2, 13.5, 6.8, 6.1, 6.8, 5.1, 11.3, 7.4, 10.8, 9, 12.9, 7.7],
    'K%': [0.19, 0.174, 0.2, 0.167, 0.172, 0.148, 0.136, 0.278, 0.167, 0.3, 0.25, 0.37, 0.182],
    'SO': [4, 4, 3, 3, 5, 4, 3, 5, 3, 6, 6, 10, 4]
}

df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "SPK/9", "SPK%", "SPSO", "TBF", "K/9", "K%"]]
y = df["SO"].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 16.7249
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.1447
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.9042
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.7855
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.5160
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.4433
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.6642
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.4018
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.4339
# Epoch 10/500
# ...

# %% [markdown]
# #CORBIN BURNES

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    "IP": [6, 6, 7, 7, 7, 6, 7, 7, 6, 6, 6, 7.1, 6.2],
    "SPK/9": [16.5, 9, 6.4, 6.4, 7.7, 10.5, 6.4, 6.4, 9, 7.5, 9, 6.1, 9.5],
    "SPK%": [0.458, 0.222, 0.185, 0.192, 0.222, 0.259, 0.192, 0.172, 0.273, 0.185, 0.25, 0.172, 0.25],
    "SPSO": [11, 6, 5, 5, 6, 7, 5, 5, 6, 5, 6, 5, 7],
    "TBF": [23, 31, 7, 23, 8, 29, 29, 17, 7, 10, 22, 23, 25],
    "K/9": [7.7, 7.7, 10.8, 9, 9, 3, 4, 2.3, 13.5, 3.4, 6.2, 3.6, 4.3],
    "K%": [0.261, 0.194, 0.286, 0.261, 0.25, 0.069, 0.138, 0.059, 0.143, 0.1, 0.136, 0.087, 0.12],
    "SO": [6, 6, 2, 6, 2, 2, 4, 1, 1, 1, 3, 2, 3]
}

df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "SPK/9", "SPK%", "SPSO", "TBF", "K/9", "K%"]]
y = df["SO"].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.4114
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.4244
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2955
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0356
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0867
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5288
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1039
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5675
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3434
# Epoch 10/500
# ...

# %% [markdown]
# #MICHAEL WACHA

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [3.2, 6, 6, 7, 6, 5.1, 5, 5.1, 6, 5, 7, 4.2, 7],
    'SPK/9': [7.4, 9, 10.5, 3.9, 10.5, 3.4, 9, 10.1, 12, 5.4, 9, 1.9, 6.4],
    'SPK%': [0.143, 0.222, 0.304, 0.115, 0.318, 0.095, 0.263, 0.24, 0.333, 0.13, 0.292, 0.05, 0.185],
    'SPSO': [3, 6, 7, 3, 7, 2, 5, 6, 8, 3, 7, 1, 5],
    'TBF': [27, 24, 18, 17, 25, 28, 23, 27, 24, 19, 28, 22, 24],
    'K/9': [6.8, 10.1, 2.1, 7.2, 13.5, 9, 12, 12.4, 3, 14.4, 3.4, 9.5, 7.9],
    'K%': [0.185, 0.25, 0.056, 0.235, 0.36, 0.25, 0.348, 0.407, 0.083, 0.421, 0.107, 0.273, 0.208],
    'SO': [5, 6, 1, 4, 9, 7, 8, 11, 2, 8, 3, 6, 5]
}

df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "SPK/9", "SPK%", "SPSO", "TBF", "K/9", "K%"]]
y = df["SO"].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# Epoch 1/500
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 40.0551
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 38.5581
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 45.0406
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.8101
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 36.0809
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.3195
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.1458
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.3104
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.3059
# Epoch 10/500
# ...

# %% [markdown]
# #SPENCER ARRIGHETTI

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [5, 6, 3, 5.2, 1.1, 4.1, 7, 4, 5, 6, 6, 6],
    'SPK/9': [12.6, 12, 12, 9.5, 13.5, 4.2, 12.9, 11.3, 10.8, 10.5, 4.5, 12],
    'SPK%': [0.304, 0.348, 0.267, 0.25, 0.167, 0.091, 0.417, 0.238, 0.25, 0.292, 0.115, 0.333],
    'SPSO': [7, 8, 4, 6, 2, 2, 10, 5, 6, 7, 3, 8],
    'TBF': [20, 25, 22, 20, 23, 27, 21, 26, 20, 19, 22, 23],
    'K/9': [8.4, 12.9, 9.6, 9.5, 10.8, 6.8, 4.5, 6.4, 12.6, 12.6, 17.5, 12.6],
    'K%': [0.25, 0.4, 0.227, 0.3, 0.261, 0.185, 0.095, 0.192, 0.35, 0.368, 0.5, 0.304],
    'SO': [5, 10, 5, 6, 6, 5, 2, 5, 7, 7, 11, 7]
}

df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "SPK/9", "SPK%", "SPSO", "TBF", "K/9", "K%"]]
y = df["SO"].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 36.6169
# Epoch 2/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 36.5465
# Epoch 3/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 30.1409
# Epoch 4/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 34.8192
# Epoch 5/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 30.3400
# Epoch 6/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.9551
# Epoch 7/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 28.0000
# Epoch 8/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.9208
# Epoch 9/500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.8298
# Epoch 10/500
# ...

# %% [markdown]
# #NICK PIVETTA

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# Organize the data into a DataFrame
data = {
    'IP': [6, 3.1, 5.1, 7, 4, 7, 4.1, 4, 7, 6.2, 6, 2.2, 6.2],
    'SPK/9': [12, 8.1, 15.2, 11.6, 9, 5.1, 10.4, 9, 12.9, 13.5, 12, 20.2, 13.5],
    'SPK%': [0.421, 0.15, 0.429, 0.375, 0.182, 0.138, 0.25, 0.2, 0.435, 0.357, 0.381, 0.316, 0.37],
    'SPSO': [8, 3, 9, 9, 4, 4, 5, 4, 10, 10, 8, 6, 10],
    'TBF': [24, 24, 18, 23, 25, 24, 34, 28, 24, 19, 27, 23, 25],
    'K/9': [3.4, 7.1, 15.8, 5.8, 1.5, 9.6, 8, 6.4, 9, 5.4, 3.9, 8.4, 12.6],
    'K%': [0.083, 0.208, 0.389, 0.13, 0.04, 0.208, 0.235, 0.179, 0.208, 0.158, 0.111, 0.217, 0.28],
    'SO': [2, 5, 7, 3, 1, 5, 8, 5, 5, 3, 3, 5, 7]
}

df = pd.DataFrame(data)

# Define the independent variables and the dependent variable
X = df[["IP", "SPK/9", "SPK%", "SPSO", "TBF", "K/9", "K%"]]
y = df["SO"].values

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for the neural network
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the neural network model
model = Sequential()
model.add(Dense(128, input_dim=X_train_scaled.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model with a modified learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mean_squared_error')

# Train the neural network model
model.fit(X_train_scaled, y_train, epochs=500, batch_size=4, verbose=1)

# Predict on the test set with the neural network
y_pred_nn = model.predict(X_test_scaled)

# Calculate performance metrics for the neural network
mse_nn = mean_squared_error(y_test, y_pred_nn)
r2_nn = r2_score(y_test, y_pred_nn)

print(f"Neural Network Mean Squared Error: {mse_nn}")
print(f"Neural Network R-squared: {r2_nn}")

# Output the first model prediction
print("Neural Network Predicted so:", y_pred_nn.flatten()[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 26.1983
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.5294
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.2008
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.9466
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.5044
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.2502
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.9349
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.1013
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.2555
# Epoch 10/500
# ...
