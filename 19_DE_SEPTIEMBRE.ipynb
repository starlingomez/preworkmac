# %% [markdown]
# <a href="https://colab.research.google.com/github/starlingomez/preworkmac/blob/master/19_DE_SEPTIEMBRE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ZACH EFLIN

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [25, 25, 24, 24, 21, 29, 23, 29, 20, 26, 15, 24, 25, 27, 24, 24, 27, 26, 22, 28, 25, 26, 23, 25, 26, 25],
    'K%': [0.2, 0.2, 0.208, 0.208, 0.286, 0.138, 0.261, 0.103, 0.1, 0.115, 0.2, 0.125, 0.28, 0.222, 0.25, 0.125, 0.222, 0.192, 0.182, 0.25, 0.12, 0.269, 0.348, 0.36, 0.154, 0.12],
    'STRIKEOUT': [5, 5, 5, 5, 6, 4, 6, 3, 2, 3, 3, 3, 7, 6, 6, 3, 6, 5, 4, 7, 3, 7, 8, 9, 4, 3]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22],    # Example TBF
    'K%': [0.28]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [6 7 8 9]
# Predicted Strikeouts: [6. 4. 6. 5.]
# Actual Strikeouts: [6 3 2 3]
# Mean Squared Error: 5.24820078912785
#
# Test Indices: [10 11 12 13]
# Predicted Strikeouts: [5.45 3.09 5.   4.89]
# Actual Strikeouts: [3 3 7 6]
# Mean Squared Error: 2.808402513421072
#
# Test Indices: [14 15 16 17]
# Predicted Strikeouts: [6.61 3.   6.   4.  ]
# Actual Strikeouts: [6 3 6 5]
# Mean Squared Error: 0.34199192445805693
#
# Test Indices: [18 19 20 21]
# Predicted Strikeouts: [4.29 6.   3.   6.  ]
# Actual Strikeouts: [4 7 3 7]
# Mean Squared Error: 0.5205570676678377
#
# Test Indices: [22 23 24 25]
# Predicted Strikeouts: [6.   7.   4.33 3.  ]
# Actual Strikeouts: [8 9 4 3]
# Mean Squared Error: 2.027132661031672
#
# Average Mean Squared Error across all folds: 2.189256991141298
# Predicted Strikeouts for Next Game: 6.608061790466309

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [25, 25, 24, 24, 21, 29, 23, 29, 20, 26, 15, 24, 25, 27, 24, 24, 27, 26, 22, 28, 25, 26, 23, 25, 26, 25],
    'K%': [0.2, 0.2, 0.208, 0.208, 0.286, 0.138, 0.261, 0.103, 0.1, 0.115, 0.2, 0.125, 0.28, 0.222, 0.25, 0.125, 0.222, 0.192, 0.182, 0.25, 0.12, 0.269, 0.348, 0.36, 0.154, 0.12],
    'STRIKEOUT': [5, 5, 5, 5, 6, 4, 6, 3, 2, 3, 3, 3, 7, 6, 6, 3, 6, 5, 4, 7, 3, 7, 8, 9, 4, 3]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [24],    # Example TBF
    'K%': [0.20]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [6 7 8 9]
# Predicted Strikeouts: [6. 4. 6. 5.]
# Actual Strikeouts: [6 3 2 3]
# Mean Squared Error: 5.24820078912785
#
# Test Indices: [10 11 12 13]
# Predicted Strikeouts: [5.45 3.09 5.   4.89]
# Actual Strikeouts: [3 3 7 6]
# Mean Squared Error: 2.808402513421072
#
# Test Indices: [14 15 16 17]
# Predicted Strikeouts: [6.61 3.   6.   4.  ]
# Actual Strikeouts: [6 3 6 5]
# Mean Squared Error: 0.34199192445805693
#
# Test Indices: [18 19 20 21]
# Predicted Strikeouts: [4.29 6.   3.   6.  ]
# Actual Strikeouts: [4 7 3 7]
# Mean Squared Error: 0.5205570676678377
#
# Test Indices: [22 23 24 25]
# Predicted Strikeouts: [6.   7.   4.33 3.  ]
# Actual Strikeouts: [8 9 4 3]
# Mean Squared Error: 2.027132661031672
#
# Average Mean Squared Error across all folds: 2.189256991141298
# Predicted Strikeouts for Next Game: 4.998904228210449

# %% [markdown]
# #brandon webb

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [24, 20, 29, 27, 23, 30, 22, 22, 29, 25, 24, 25, 27, 26, 24, 28, 28, 27, 26, 24, 27, 26, 34, 24, 27, 27, 27, 23, 26, 27, 20],
    'K%': [0.208, 0.25, 0.103, 0.148, 0.217, 0.133, 0.182, 0.273, 0.207, 0.2, 0.25, 0.32, 0.222, 0.231, 0.208, 0.179, 0.286, 0.222, 0.231, 0.167, 0.148, 0.154, 0.176, 0.167, 0.296, 0.259, 0.222, 0.174, 0.154, 0.111, 0.2],
    'STRIKEOUT': [5, 5, 3, 4, 5, 4, 4, 6, 6, 5, 6, 8, 6, 6, 5, 5, 8, 6, 6, 4, 4, 4, 6, 4, 8, 7, 6, 4, 4, 3, 4]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [21],    # Example TBF
    'K%': [0.2281]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 6  7  8  9 10]
# Predicted Strikeouts: [5. 5. 4. 5. 5.]
# Actual Strikeouts: [4 6 6 5 6]
# Mean Squared Error: 1.400176540374605
#
# Test Indices: [11 12 13 14 15]
# Predicted Strikeouts: [6.   5.98 5.22 5.   4.  ]
# Actual Strikeouts: [8 6 6 5 5]
# Mean Squared Error: 1.1212344947588462
#
# Test Indices: [16 17 18 19 20]
# Predicted Strikeouts: [6.18 6.   6.   4.   4.  ]
# Actual Strikeouts: [8 6 6 4 4]
# Mean Squared Error: 0.6620164535144568
#
# Test Indices: [21 22 23 24 25]
# Predicted Strikeouts: [4.   4.1  4.   8.   6.03]
# Actual Strikeouts: [4 6 4 8 7]
# Mean Squared Error: 0.9116897252422064
#
# Test Indices: [26 27 28 29 30]
# Predicted Strikeouts: [6.   3.98 4.   3.   4.55]
# Actual Strikeouts: [6 4 4 3 4]
# Mean Squared Error: 0.059599404867628894
#
# Average Mean Squared Error across all folds: 0.8309433237515487
# Predicted Strikeouts for Next Game: 4.994294166564941

# %% [markdown]
# #SIMEON WOOD

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [21, 23, 19, 20, 21, 21, 18, 20, 18, 26, 20, 24, 22, 23, 23, 21, 20, 20, 21, 25, 20, 21, 20, 19, 19, 15],
    'K%': [0.238, 0.261, 0.105, 0.4, 0.095, 0.095, 0.056, 0.2, 0.333, 0.231, 0.2, 0.25, 0.182, 0.174, 0.174, 0.333, 0.25, 0.1, 0.286, 0.28, 0.05, 0.333, 0.15, 0.105, 0.105, 0.2],
    'STRIKEOUT': [5, 6, 2, 8, 2, 2, 1, 4, 6, 6, 4, 6, 4, 4, 4, 7, 5, 2, 6, 7, 1, 7, 3, 2, 2, 3]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [21],    # Example TBF
    'K%': [0.18]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [6 7 8 9]
# Predicted Strikeouts: [2.   2.   7.14 2.01]
# Actual Strikeouts: [1 4 6 6]
# Mean Squared Error: 5.565227863531476
#
# Test Indices: [10 11 12 13]
# Predicted Strikeouts: [4.   5.57 2.   2.  ]
# Actual Strikeouts: [4 6 4 4]
# Mean Squared Error: 2.0421666631446413
#
# Test Indices: [14 15 16 17]
# Predicted Strikeouts: [4.   6.28 5.57 2.03]
# Actual Strikeouts: [4 7 5 2]
# Mean Squared Error: 0.2132345954875774
#
# Test Indices: [18 19 20 21]
# Predicted Strikeouts: [5.35 6.3  1.69 7.  ]
# Actual Strikeouts: [6 7 1 7]
# Mean Squared Error: 0.3454412874966266
#
# Test Indices: [22 23 24 25]
# Predicted Strikeouts: [2. 2. 2. 4.]
# Actual Strikeouts: [3 2 2 3]
# Mean Squared Error: 0.4998831857121786
#
# Average Mean Squared Error across all folds: 1.7331907190745
# Predicted Strikeouts for Next Game: 3.9571142196655273

# %% [markdown]
# #CHRIS SALES

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 20, 29, 27, 25, 22, 25, 25, 26, 26, 22, 27, 27, 18, 24, 23, 24, 20, 24, 25, 25, 25, 25, 28, 24, 27, 23, 23],
    'K%': [0.318, 0.3, 0.241, 0.259, 0.24, 0.409, 0.4, 0.36, 0.346, 0.308, 0.182, 0.37, 0.259, 0.444, 0.458, 0.391, 0.375, 0.2, 0.375, 0.24, 0.4, 0.48, 0.4, 0.143, 0.25, 0.333, 0.304, 0.261],
    'STRIKEOUT': [7, 6, 7, 7, 6, 9, 10, 9, 9, 8, 4, 10, 7, 8, 11, 9, 9, 4, 9, 6, 10, 12, 10, 4, 6, 9, 7, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.24]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 8  9 10 11]
# Predicted Strikeouts: [7. 6. 6. 9.]
# Actual Strikeouts: [ 9  8  4 10]
# Mean Squared Error: 3.250050506131686
#
# Test Indices: [12 13 14 15]
# Predicted Strikeouts: [7. 9. 9. 9.]
# Actual Strikeouts: [ 7  8 11  9]
# Mean Squared Error: 1.249949464999247
#
# Test Indices: [16 17 18 19]
# Predicted Strikeouts: [10.  4. 10.  6.]
# Actual Strikeouts: [9 4 9 6]
# Mean Squared Error: 0.49968094821139175
#
# Test Indices: [20 21 22 23]
# Predicted Strikeouts: [10.   11.   10.    4.42]
# Actual Strikeouts: [10 12 10  4]
# Mean Squared Error: 0.29412009050406596
#
# Test Indices: [24 25 26 27]
# Predicted Strikeouts: [6.55 7.87 6.56 6.55]
# Actual Strikeouts: [6 9 7 6]
# Mean Squared Error: 0.5193317884254043
#
# Average Mean Squared Error across all folds: 1.162626559654359
# Predicted Strikeouts for Next Game: 6.000146865844727

# %% [markdown]
# #KEVIN GAUSMAN

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [16, 11, 21, 21, 28, 26, 21, 20, 26, 21, 22, 27, 32, 23, 27, 26, 26, 27, 27, 27, 34, 23, 30, 27, 22, 23, 24, 26, 31],
    'K%': [0.375, 0, 0.19, 0.286, 0.071, 0.192, 0.381, 0.3, 0.231, 0.476, 0.136, 0.111, 0.313, 0.261, 0.148, 0.192, 0.269, 0.37, 0.111, 0.185, 0.235, 0.087, 0.067, 0.185, 0.227, 0.435, 0.167, 0.192, 0.097],
    'STRIKEOUT': [6, 0, 4, 6, 2, 5, 8, 6, 6, 10, 3, 3, 10, 6, 4, 5, 7, 10, 3, 5, 8, 2, 2, 5, 5, 10, 4, 5, 3]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22.5],    # Example TBF
    'K%': [0.22]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 9 10 11 12]
# Predicted Strikeouts: [8. 2. 2. 6.]
# Actual Strikeouts: [10  3  3 10]
# Mean Squared Error: 5.501346190918099
#
# Test Indices: [13 14 15 16]
# Predicted Strikeouts: [6. 3. 5. 6.]
# Actual Strikeouts: [6 4 5 7]
# Mean Squared Error: 0.5002413329618207
#
# Test Indices: [17 18 19 20]
# Predicted Strikeouts: [10.    3.    4.    6.34]
# Actual Strikeouts: [10  3  5  8]
# Mean Squared Error: 0.9357070381061163
#
# Test Indices: [21 22 23 24]
# Predicted Strikeouts: [2.01 2.   5.   4.95]
# Actual Strikeouts: [2 2 5 5]
# Mean Squared Error: 0.0007645440383186042
#
# Test Indices: [25 26 27 28]
# Predicted Strikeouts: [8.01 3.98 5.   2.01]
# Actual Strikeouts: [10  4  5  3]
# Mean Squared Error: 1.242033944322344
#
# Average Mean Squared Error across all folds: 1.6360186100693397
# Predicted Strikeouts for Next Game: 4.995294570922852

# %% [markdown]
# #LOGAN GILBERT

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [26, 23, 28, 23, 26, 24, 27, 22, 24, 27, 21, 26, 25, 26, 26, 28, 23, 25, 27, 23, 27, 15, 22, 24, 27, 24, 22, 23, 27, 25],
    'K%': [0.308, 0.304, 0.286, 0.261, 0.231, 0.375, 0.222, 0.182, 0.292, 0.037, 0.19, 0.192, 0.2, 0.308, 0.346, 0.214, 0.13, 0.24, 0.259, 0.391, 0.296, 0.267, 0.318, 0.25, 0.222, 0.292, 0.455, 0.391, 0.37, 0.28],
    'STRIKEOUT': [8, 7, 8, 6, 6, 9, 6, 4, 7, 1, 4, 5, 5, 8, 9, 6, 3, 6, 7, 9, 8, 4, 7, 6, 6, 7, 10, 9, 10, 7]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [25],    # Example TBF
    'K%': [0.27]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6 7 8 9]
# Predicted Strikeouts: [7. 6. 6. 7. 6.]
# Actual Strikeouts: [9 6 4 7 1]
# Mean Squared Error: 6.601189419194361
#
# Test Indices: [10 11 12 13 14]
# Predicted Strikeouts: [4. 1. 1. 8. 8.]
# Actual Strikeouts: [4 5 5 8 9]
# Mean Squared Error: 6.585115208805201
#
# Test Indices: [15 16 17 18 19]
# Predicted Strikeouts: [3.48 2.55 6.   6.   8.61]
# Actual Strikeouts: [6 3 6 7 9]
# Mean Squared Error: 1.54078684180065
#
# Test Indices: [20 21 22 23 24]
# Predicted Strikeouts: [7.92 6.   7.6  6.   6.  ]
# Actual Strikeouts: [8 4 7 6 6]
# Mean Squared Error: 0.8736465331005092
#
# Test Indices: [25 26 27 28 29]
# Predicted Strikeouts: [7.   8.6  9.   9.   6.47]
# Actual Strikeouts: [ 7 10  9 10  7]
# Mean Squared Error: 0.6453160225908959
#
# Average Mean Squared Error across all folds: 3.2492108050983233
# Predicted Strikeouts for Next Game: 6.399970054626465

# %% [markdown]
# #EDWARD CABRERA

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 25, 20, 18, 12, 17, 17, 22, 23, 20, 19, 27, 20, 24, 23, 24, 24, 22],
    'K%': [0.455, 0.28, 0.2, 0.5, 0.083, 0.235, 0.412, 0.045, 0.261, 0.35, 0.421, 0.148, 0.1, 0.125, 0.348, 0.125, 0.25, 0.409],
    'STRIKEOUT': [10, 7, 4, 9, 1, 4, 7, 1, 6, 7, 8, 4, 2, 3, 8, 3, 6, 9]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22],    # Example TBF
    'K%': [0.235]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [3 4 5]
# Predicted Strikeouts: [5.11 4.   4.  ]
# Actual Strikeouts: [9 1 4]
# Mean Squared Error: 8.046284780818345
#
# Test Indices: [6 7 8]
# Predicted Strikeouts: [8.97 4.02 4.02]
# Actual Strikeouts: [7 1 6]
# Mean Squared Error: 5.6468123488595365
#
# Test Indices: [ 9 10 11]
# Predicted Strikeouts: [7. 7. 1.]
# Actual Strikeouts: [7 8 4]
# Mean Squared Error: 3.3321485267894673
#
# Test Indices: [12 13 14]
# Predicted Strikeouts: [1. 1. 7.]
# Actual Strikeouts: [2 3 8]
# Mean Squared Error: 1.9988005243233147
#
# Test Indices: [15 16 17]
# Predicted Strikeouts: [3. 4. 8.]
# Actual Strikeouts: [3 6 9]
# Mean Squared Error: 1.6693447878557965
#
# Average Mean Squared Error across all folds: 4.138678193729292
# Predicted Strikeouts for Next Game: 3.999816417694092

# %% [markdown]
# #ZACK LITTLE

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 20, 22, 25, 27, 25, 23, 23, 25, 21, 28, 29, 26, 16, 21, 19, 18, 21, 28, 26, 25, 20, 23, 18, 22, 20, 20],
    'K%': [0.273, 0.25, 0.182, 0.28, 0.259, 0.24, 0.304, 0.13, 0.12, 0.333, 0.321, 0.069, 0.115, 0.125, 0.238, 0.316, 0.222, 0.238, 0.107, 0.231, 0.2, 0.15, 0.217, 0.167, 0.091, 0.2, 0.25],
    'STRIKEOUT': [6, 5, 4, 7, 7, 6, 7, 3, 3, 7, 9, 2, 3, 2, 5, 6, 4, 5, 3, 6, 5, 3, 5, 3, 2, 4, 5]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.235]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 7  8  9 10]
# Predicted Strikeouts: [4.73 4.73 5.73 7.  ]
# Actual Strikeouts: [3 3 7 9]
# Mean Squared Error: 2.9041787970074324
#
# Test Indices: [11 12 13 14]
# Predicted Strikeouts: [3.71 3.   3.09 4.  ]
# Actual Strikeouts: [2 3 2 5]
# Mean Squared Error: 1.2806448513515534
#
# Test Indices: [15 16 17 18]
# Predicted Strikeouts: [6.3  3.67 5.   2.  ]
# Actual Strikeouts: [6 4 5 3]
# Mean Squared Error: 0.29842202874158374
#
# Test Indices: [19 20 21 22]
# Predicted Strikeouts: [4.09 4.09 3.01 3.99]
# Actual Strikeouts: [6 5 3 5]
# Mean Squared Error: 1.370228601275926
#
# Test Indices: [23 24 25 26]
# Predicted Strikeouts: [2.91 2.79 4.23 5.  ]
# Actual Strikeouts: [3 2 4 5]
# Mean Squared Error: 0.1726559265970451
#
# Average Mean Squared Error across all folds: 1.2052260409947082
# Predicted Strikeouts for Next Game: 5.997831344604492

# %% [markdown]
# #LUIS SEVERION

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    "TBF": [27, 21, 20, 24, 24, 27, 26, 22, 28, 26, 25, 27, 26, 28, 22, 28, 28, 27, 25, 23, 16, 24, 22, 32, 23, 23, 26, 25, 22],
    "K%": [0.222, 0.333, 0.2, 0.167, 0.208, 0.185, 0.231, 0.182, 0.107, 0.231, 0.16, 0.148, 0.077, 0.036, 0.455, 0.107, 0.107, 0.148, 0.28, 0.261, 0.125, 0.208, 0.364, 0.25, 0.217, 0.391, 0.192, 0.32, 0.227],
    "STRIKEOUT": [6, 7, 4, 4, 5, 5, 6, 4, 3, 6, 4, 4, 2, 1, 10, 3, 3, 4, 7, 6, 2, 5, 8, 8, 5, 9, 5, 8, 5]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [24],    # Example TBF
    'K%': [0.2662]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 9 10 11 12]
# Predicted Strikeouts: [6.   4.   4.22 4.22]
# Actual Strikeouts: [6 4 4 2]
# Mean Squared Error: 1.2421720194045065
#
# Test Indices: [13 14 15 16]
# Predicted Strikeouts: [2.6  6.44 3.   3.  ]
# Actual Strikeouts: [ 1 10  3  3]
# Mean Squared Error: 3.801997339341483
#
# Test Indices: [17 18 19 20]
# Predicted Strikeouts: [4.   6.   6.74 3.2 ]
# Actual Strikeouts: [4 7 6 2]
# Mean Squared Error: 0.7474519036225189
#
# Test Indices: [21 22 23 24]
# Predicted Strikeouts: [5. 7. 6. 5.]
# Actual Strikeouts: [5 8 8 5]
# Mean Squared Error: 1.2487822247420581
#
# Test Indices: [25 26 27 28]
# Predicted Strikeouts: [7.82 4.95 7.   5.47]
# Actual Strikeouts: [9 5 8 5]
# Mean Squared Error: 0.655954192988645
#
# Average Mean Squared Error across all folds: 1.5392715360198423
# Predicted Strikeouts for Next Game: 5.000323295593262

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    "TBF": [27, 21, 20, 24, 24, 27, 26, 22, 28, 26, 25, 27, 26, 28, 22, 28, 28, 27, 25, 23, 16, 24, 22, 32, 23, 23, 26, 25, 22],
    "K%": [0.222, 0.333, 0.2, 0.167, 0.208, 0.185, 0.231, 0.182, 0.107, 0.231, 0.16, 0.148, 0.077, 0.036, 0.455, 0.107, 0.107, 0.148, 0.28, 0.261, 0.125, 0.208, 0.364, 0.25, 0.217, 0.391, 0.192, 0.32, 0.227],
    "STRIKEOUT": [6, 7, 4, 4, 5, 5, 6, 4, 3, 6, 4, 4, 2, 1, 10, 3, 3, 4, 7, 6, 2, 5, 8, 8, 5, 9, 5, 8, 5]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [25],    # Example TBF
    'K%': [0.2662]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 9 10 11 12]
# Predicted Strikeouts: [6.   4.   4.22 4.22]
# Actual Strikeouts: [6 4 4 2]
# Mean Squared Error: 1.2421720194045065
#
# Test Indices: [13 14 15 16]
# Predicted Strikeouts: [2.6  6.44 3.   3.  ]
# Actual Strikeouts: [ 1 10  3  3]
# Mean Squared Error: 3.801997339341483
#
# Test Indices: [17 18 19 20]
# Predicted Strikeouts: [4.   6.   6.74 3.2 ]
# Actual Strikeouts: [4 7 6 2]
# Mean Squared Error: 0.7474519036225189
#
# Test Indices: [21 22 23 24]
# Predicted Strikeouts: [5. 7. 6. 5.]
# Actual Strikeouts: [5 8 8 5]
# Mean Squared Error: 1.2487822247420581
#
# Test Indices: [25 26 27 28]
# Predicted Strikeouts: [7.82 4.95 7.   5.47]
# Actual Strikeouts: [9 5 8 5]
# Mean Squared Error: 0.655954192988645
#
# Average Mean Squared Error across all folds: 1.5392715360198423
# Predicted Strikeouts for Next Game: 7.0003252029418945

# %% [markdown]
# #JAVIER ASSAD

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 21, 21, 20, 22, 20, 25, 20, 23, 24, 23, 22, 27, 22, 22, 20, 15, 17, 24, 18, 18, 21, 23, 27, 25, 24, 26],
    'K%': [0.227, 0.333, 0.286, 0.15, 0.227, 0.05, 0.16, 0.2, 0.304, 0.167, 0.348, 0.318, 0.259, 0.182, 0.318, 0, 0, 0.118, 0.208, 0.167, 0.056, 0.095, 0.304, 0.111, 0.16, 0.208, 0.192],
    'STRIKEOUT': [5, 7, 6, 3, 5, 1, 4, 4, 7, 4, 8, 7, 7, 4, 7, 0, 0, 2, 5, 3, 1, 2, 7, 3, 4, 5, 5]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22.5],    # Example TBF
    'K%': [0.19]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 7  8  9 10]
# Predicted Strikeouts: [3.   5.   4.27 5.56]
# Actual Strikeouts: [4 7 4 8]
# Mean Squared Error: 2.7550046715984564
#
# Test Indices: [11 12 13 14]
# Predicted Strikeouts: [7. 5. 4. 7.]
# Actual Strikeouts: [7 7 4 7]
# Mean Squared Error: 1.0000682102149199
#
# Test Indices: [15 16 17 18]
# Predicted Strikeouts: [1. 1. 1. 4.]
# Actual Strikeouts: [0 0 2 5]
# Mean Squared Error: 0.9987284171331083
#
# Test Indices: [19 20 21 22]
# Predicted Strikeouts: [3.99 1.   1.   7.  ]
# Actual Strikeouts: [3 1 2 7]
# Mean Squared Error: 0.4959247264603279
#
# Test Indices: [23 24 25 26]
# Predicted Strikeouts: [2.77 4.   5.   4.  ]
# Actual Strikeouts: [3 4 5 5]
# Mean Squared Error: 0.2632367334270782
#
# Average Mean Squared Error across all folds: 1.102592551766778
# Predicted Strikeouts for Next Game: 4.000568389892578

# %% [markdown]
# #KIKUCHI

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 20, 23, 23, 23, 27, 24, 27, 20, 27, 17, 25, 22, 22, 18, 15, 20, 24, 27, 24, 23, 24, 22, 23, 21, 25, 22, 26, 26, 26],
    'K%': [0.182, 0.35, 0.391, 0.391, 0.174, 0.111, 0.292, 0.111, 0.45, 0.222, 0, 0.16, 0.273, 0.227, 0.389, 0.2, 0.35, 0.208, 0.481, 0.25, 0.348, 0.208, 0.5, 0.348, 0.238, 0.28, 0.182, 0.462, 0.231, 0.231],
    'STRIKEOUT': [4, 7, 9, 9, 4, 3, 7, 3, 9, 6, 0, 4, 6, 5, 7, 3, 7, 5, 13, 6, 8, 5, 11, 8, 5, 7, 4, 12, 6, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22],    # Example TBF
    'K%': [0.25]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6 7 8 9]
# Predicted Strikeouts: [4. 4. 4. 7. 4.]
# Actual Strikeouts: [3 7 3 9 6]
# Mean Squared Error: 3.7985153849813287
#
# Test Indices: [10 11 12 13 14]
# Predicted Strikeouts: [3.16 3.   6.14 6.14 7.  ]
# Actual Strikeouts: [0 4 6 5 7]
# Mean Squared Error: 2.4582837684269294
#
# Test Indices: [15 16 17 18 19]
# Predicted Strikeouts: [1.19 7.   4.   9.   5.73]
# Actual Strikeouts: [ 3  7  5 13  6]
# Mean Squared Error: 4.07377968738713
#
# Test Indices: [20 21 22 23 24]
# Predicted Strikeouts: [ 7.    5.   10.71  7.    5.  ]
# Actual Strikeouts: [ 8  5 11  8  5]
# Mean Squared Error: 0.41610372747850305
#
# Test Indices: [25 26 27 28 29]
# Predicted Strikeouts: [6.01 4.   9.28 5.58 5.58]
# Actual Strikeouts: [ 7  4 12  6  6]
# Mean Squared Error: 1.7508758586840032
#
# Average Mean Squared Error across all folds: 2.499511685391579
# Predicted Strikeouts for Next Game: 5.967212677001953
