# %% [markdown]
# <a href="https://colab.research.google.com/github/starlingomez/preworkmac/blob/master/30_de_octubre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/kyleskom/NBA-Machine-Learning-Sports-Betting.git
! mv -v ./NBA-Machine-Learning-Sports-Betting/* .
! pip3 install colorama
! pip3 install pandas=2.1.2
! pip3 install sbrscrape
! pip3 install tensorflow==2.14.0
! pip3 install tensorflow-meta
! pip3 install xgboost
! pip3 install tqdm
! pip3 install flask
! pip3 install scikit-learn
# Out:
# Cloning into 'NBA-Machine-Learning-Sports-Betting'...
# remote: Enumerating objects: 18800, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 18800 (delta 13), reused 27 (delta 9), pack-reused 18760 (from 1)
# Receiving objects: 100% (18800/18800), 431.01 MiB | 20.65 MiB/s, done.
# Resolving deltas: 100% (6911/6911), done.
# Updating files: 100% (59/59), done.
# renamed './NBA-Machine-Learning-Sports-Betting/ColabNotebook.ipynb' -> './ColabNotebook.ipynb'
# renamed './NBA-Machine-Learning-Sports-Betting/config.toml' -> './config.toml'
# renamed './NBA-Machine-Learning-Sports-Betting/Data' -> './Data'
# renamed './NBA-Machine-Learning-Sports-Betting/Flask' -> './Flask'
# renamed './NBA-Machine-Learning-Sports-Betting/main.py' -> './main.py'
# renamed './NBA-Machine-Learning-Sports-Betting/Models' -> './Models'
# renamed './NBA-Machine-Learning-Sports-Betting/notes.txt' -> './notes.txt'
# ...

# %%
! python3 main.py -xgb -nn -odds=fanduel
# Out:
# 2024-10-30 19:24:32.467357: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-30 19:24:32.522278: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-30 19:24:32.522339: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-30 19:24:32.522383: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-30 19:24:32.532677: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# ...
