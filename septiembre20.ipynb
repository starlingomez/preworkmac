# %% [markdown]
# <a href="https://colab.research.google.com/github/starlingomez/preworkmac/blob/master/septiembre20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #JAMESON TAILLION

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    "TBF": [18, 26, 27, 23, 23, 21, 26, 24, 25, 23, 26, 27, 24, 25, 22, 23, 26, 20, 24, 24, 25, 23, 27, 26, 25, 24],
    "K%": [0.222, 0.154, 0.037, 0.304, 0.087, 0.19, 0.115, 0.167, 0.24, 0.217, 0.115, 0.37, 0.208, 0.28, 0.318, 0.13, 0.115, 0.2, 0.167, 0.167, 0.24, 0.217, 0.111, 0.115, 0.24, 0.25],
    "STRIKEOUT": [4, 4, 1, 7, 2, 4, 3, 4, 6, 5, 3, 10, 5, 7, 7, 3, 3, 4, 4, 4, 6, 5, 3, 3, 6, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [24],    # Example TBF
    'K%': [0.206]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [6 7 8 9]
# Predicted Strikeouts: [2. 4. 4. 4.]
# Actual Strikeouts: [3 4 6 5]
# Mean Squared Error: 1.499939681040189
#
# Test Indices: [10 11 12 13]
# Predicted Strikeouts: [3. 7. 4. 6.]
# Actual Strikeouts: [ 3 10  5  7]
# Mean Squared Error: 2.7559393823884193
#
# Test Indices: [14 15 16 17]
# Predicted Strikeouts: [7.   3.   3.   3.82]
# Actual Strikeouts: [7 3 3 4]
# Mean Squared Error: 0.007947056239785866
#
# Test Indices: [18 19 20 21]
# Predicted Strikeouts: [4. 4. 6. 5.]
# Actual Strikeouts: [4 4 6 5]
# Mean Squared Error: 8.626369663033984e-08
#
# Test Indices: [22 23 24 25]
# Predicted Strikeouts: [1. 3. 6. 6.]
# Actual Strikeouts: [3 3 6 6]
# Mean Squared Error: 0.9986097898157738
#
# Average Mean Squared Error across all folds: 1.052487199149573
# Predicted Strikeouts for Next Game: 4.029579162597656

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [27, 27, 25, 27, 26, 24, 23, 31, 26, 24, 27, 24, 26, 28, 25, 29, 25, 31, 16, 28, 25, 15, 21, 25, 24, 21, 27, 26, 26],
    'K%': [0.111, 0.185, 0.36, 0.148, 0.154, 0.292, 0.304, 0.161, 0.269, 0.125, 0.148, 0.333, 0.308, 0.143, 0.28, 0.207, 0.2, 0.194, 0.188, 0.107, 0.24, 0.267, 0.238, 0.08, 0.375, 0.19, 0.259, 0.308, 0.231],
    'STRIKEOUT': [3, 5, 9, 4, 4, 7, 7, 5, 7, 3, 4, 8, 8, 4, 7, 6, 5, 6, 3, 3, 6, 4, 5, 2, 9, 4, 7, 8, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [25],    # Example TBF
    'K%': [0.24]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 9 10 11 12]
# Predicted Strikeouts: [3. 4. 7. 7.]
# Actual Strikeouts: [3 4 8 8]
# Mean Squared Error: 0.5000212753646451
#
# Test Indices: [13 14 15 16]
# Predicted Strikeouts: [3.   7.   5.   5.01]
# Actual Strikeouts: [4 7 6 5]
# Mean Squared Error: 0.49968313508315987
#
# Test Indices: [17 18 19 20]
# Predicted Strikeouts: [5. 5. 3. 7.]
# Actual Strikeouts: [6 3 3 6]
# Mean Squared Error: 1.4992589641397558
#
# Test Indices: [21 22 23 24]
# Predicted Strikeouts: [5.8 5.8 3.  9. ]
# Actual Strikeouts: [4 5 2 9]
# Mean Squared Error: 1.2229834891260367
#
# Test Indices: [25 26 27 28]
# Predicted Strikeouts: [4.29 6.04 8.   5.75]
# Actual Strikeouts: [4 7 8 6]
# Mean Squared Error: 0.2688030604763867
#
# Average Mean Squared Error across all folds: 0.7981499848379968
# Predicted Strikeouts for Next Game: 5.999212265014648

# %% [markdown]
# #NICK MARTINEZ

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [23, 25, 27, 25, 21, 20, 22, 26, 22, 13, 23, 26, 24, 22],
    'K%': [0.13, 0.24, 0.111, 0.12, 0.095, 0.25, 0.318, 0.154, 0.136, 0.077, 0.13, 0.269, 0.208, 0.273],
    'STRIKEOUT': [3, 6, 3, 3, 2, 5, 7, 4, 3, 1, 3, 7, 5, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.2198]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [4 5]
# Predicted Strikeouts: [3. 6.]
# Actual Strikeouts: [2 5]
# Mean Squared Error: 0.9992489713457928
#
# Test Indices: [6 7]
# Predicted Strikeouts: [6. 3.]
# Actual Strikeouts: [7 4]
# Mean Squared Error: 1.0015503072862941
#
# Test Indices: [8 9]
# Predicted Strikeouts: [3. 2.]
# Actual Strikeouts: [3 1]
# Mean Squared Error: 0.5011371912907236
#
# Test Indices: [10 11]
# Predicted Strikeouts: [3.   4.72]
# Actual Strikeouts: [3 7]
# Mean Squared Error: 2.6039449608999803
#
# Test Indices: [12 13]
# Predicted Strikeouts: [4.05 7.  ]
# Actual Strikeouts: [5 6]
# Mean Squared Error: 0.9542496455839
#
# Average Mean Squared Error across all folds: 1.2120262152813381
# Predicted Strikeouts for Next Game: 4.999790191650391

# %% [markdown]
# #JOSE BERRIO

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [23, 24, 25, 27, 25, 20, 25, 21, 25, 25, 25, 27, 25, 22, 26, 23, 27, 22, 28, 24, 22, 28, 26, 28, 24, 28, 29, 22, 23, 25],
    'K%': [0.261, 0.083, 0.24, 0.259, 0.24, 0.05, 0.12, 0.333, 0.16, 0.24, 0.2, 0.185, 0.08, 0.182, 0.038, 0.13, 0.296, 0.045, 0.357, 0, 0.227, 0.179, 0.231, 0.286, 0.208, 0.25, 0.207, 0.227, 0.217, 0.16],
    'STRIKEOUT': [6, 2, 6, 7, 6, 1, 3, 7, 4, 6, 5, 5, 2, 4, 1, 3, 8, 1, 10, 0, 5, 5, 6, 8, 5, 7, 6, 5, 5, 4]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [25],    # Example TBF
    'K%': [0.2352]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6 7 8 9]
# Predicted Strikeouts: [2. 2. 6. 2. 6.]
# Actual Strikeouts: [1 3 7 4 6]
# Mean Squared Error: 1.3991469773305198
#
# Test Indices: [10 11 12 13 14]
# Predicted Strikeouts: [4.   4.16 2.92 3.24 2.92]
# Actual Strikeouts: [5 5 2 4 1]
# Mean Squared Error: 1.3604446386804512
#
# Test Indices: [15 16 17 18 19]
# Predicted Strikeouts: [3. 7. 1. 7. 1.]
# Actual Strikeouts: [ 3  8  1 10  0]
# Mean Squared Error: 2.2028579426724946
#
# Test Indices: [20 21 22 23 24]
# Predicted Strikeouts: [4.84 5.4  5.43 8.98 5.  ]
# Actual Strikeouts: [5 5 6 8 5]
# Mean Squared Error: 0.2963772382976913
#
# Test Indices: [25 26 27 28 29]
# Predicted Strikeouts: [6.16 5.02 5.   5.   4.  ]
# Actual Strikeouts: [7 6 5 5 4]
# Mean Squared Error: 0.3329735134707789
#
# Average Mean Squared Error across all folds: 1.118360062090387
# Predicted Strikeouts for Next Game: 6.000056266784668

# %% [markdown]
# #CHARLIE MORTON

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 25, 24, 24, 25, 24, 24, 18, 24, 28, 23, 23, 23, 25, 24, 24, 24, 23, 17, 24, 18, 25, 20, 25, 27, 22, 28, 23],
    'K%': [0.273, 0.16, 0.333, 0.167, 0.24, 0.208, 0.292, 0.222, 0.333, 0.25, 0.261, 0.13, 0.348, 0.16, 0.292, 0.208, 0.208, 0.174, 0.118, 0.25, 0.167, 0.32, 0.35, 0.24, 0.259, 0.364, 0.25, 0.261],
    'STRIKEOUT': [6, 4, 8, 4, 6, 5, 7, 4, 8, 7, 6, 3, 8, 4, 7, 5, 5, 4, 2, 6, 3, 8, 7, 6, 7, 8, 7, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.2585]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 8  9 10 11]
# Predicted Strikeouts: [8. 6. 6. 4.]
# Actual Strikeouts: [8 7 6 3]
# Mean Squared Error: 0.49989937945673546
#
# Test Indices: [12 13 14 15]
# Predicted Strikeouts: [7.59 4.   7.   5.  ]
# Actual Strikeouts: [8 4 7 5]
# Mean Squared Error: 0.04124640003806235
#
# Test Indices: [16 17 18 19]
# Predicted Strikeouts: [5.   3.63 3.   6.59]
# Actual Strikeouts: [5 4 2 6]
# Mean Squared Error: 0.3709167521792125
#
# Test Indices: [20 21 22 23]
# Predicted Strikeouts: [3.59 7.   7.65 6.  ]
# Actual Strikeouts: [3 8 7 6]
# Mean Squared Error: 0.4420453436322873
#
# Test Indices: [24 25 26 27]
# Predicted Strikeouts: [6.11 7.97 7.   6.  ]
# Actual Strikeouts: [7 8 7 6]
# Mean Squared Error: 0.1961265266151031
#
# Average Mean Squared Error across all folds: 0.31004688038428013
# Predicted Strikeouts for Next Game: 6.000298976898193

# %% [markdown]
# #VALENTE BELLOZO

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [18, 23, 18, 24, 26, 23, 27, 21, 22, 25, 23],
    'K%': [0.111, 0.348, 0.278, 0.167, 0.154, 0.174, 0.037, 0.19, 0.045, 0.08, 0.174],
    'STRIKEOUT': [2, 8, 5, 4, 4, 4, 1, 4, 1, 2, 4]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.15]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [6]
# Predicted Strikeouts: [3.62]
# Actual Strikeouts: [1]
# Mean Squared Error: 6.852934246298048
#
# Test Indices: [7]
# Predicted Strikeouts: [4.]
# Actual Strikeouts: [4]
# Mean Squared Error: 1.0027179087046534e-10
#
# Test Indices: [8]
# Predicted Strikeouts: [1.01]
# Actual Strikeouts: [1]
# Mean Squared Error: 3.2518455782337696e-05
#
# Test Indices: [9]
# Predicted Strikeouts: [1.]
# Actual Strikeouts: [2]
# Mean Squared Error: 0.9987010408418087
#
# Test Indices: [10]
# Predicted Strikeouts: [4.]
# Actual Strikeouts: [4]
# Mean Squared Error: 7.130438461899757e-10
#
# Average Mean Squared Error across all folds: 1.570333561281791
# Predicted Strikeouts for Next Game: 2.0000858306884766

# %% [markdown]
# #DAVID PETERSON

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 28, 24, 24, 23, 25, 20, 25, 23, 22, 24, 22, 26, 27, 29, 26, 25, 24, 28],
    'K%': [0.136, 0.071, 0.042, 0.25, 0.348, 0.08, 0.25, 0.2, 0.174, 0.318, 0.167, 0.227, 0.154, 0.296, 0.069, 0.154, 0.44, 0.083, 0.214],
    'STRIKEOUT': [3, 2, 1, 6, 8, 2, 5, 5, 4, 7, 4, 5, 4, 8, 2, 4, 11, 2, 6]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [25],    # Example TBF
    'K%': [0.2657]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [4 5 6]
# Predicted Strikeouts: [6. 2. 6.]
# Actual Strikeouts: [8 2 5]
# Mean Squared Error: 1.667732347416333
#
# Test Indices: [7 8 9]
# Predicted Strikeouts: [2. 2. 6.]
# Actual Strikeouts: [5 4 7]
# Mean Squared Error: 4.662869161355995
#
# Test Indices: [10 11 12]
# Predicted Strikeouts: [2.   5.78 2.  ]
# Actual Strikeouts: [4 5 4]
# Mean Squared Error: 2.8656050385963
#
# Test Indices: [13 14 15]
# Predicted Strikeouts: [5.99 1.   4.  ]
# Actual Strikeouts: [8 2 4]
# Mean Squared Error: 1.673250397932847
#
# Test Indices: [16 17 18]
# Predicted Strikeouts: [8. 2. 5.]
# Actual Strikeouts: [11  2  6]
# Mean Squared Error: 3.3350718079138346
#
# Average Mean Squared Error across all folds: 2.840905750643062
# Predicted Strikeouts for Next Game: 5.999718189239502

# %% [markdown]
# #CHRISTOPHER SANCHEZ

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [20, 22, 26, 24, 18, 22, 27, 27, 26, 24, 24, 21, 19, 25, 22, 29, 22, 24, 23, 29, 25, 25, 27, 29, 27, 26, 27, 23, 27],
    'K%': [0.4, 0.045, 0.231, 0.417, 0.167, 0.045, 0.185, 0.185, 0.308, 0.083, 0.292, 0.143, 0.105, 0.2, 0.182, 0.31, 0.136, 0.208, 0.087, 0.069, 0.28, 0.08, 0.148, 0.138, 0.296, 0.308, 0.259, 0.174, 0.259],
    'STRIKEOUT': [8, 1, 6, 10, 3, 1, 5, 5, 8, 2, 7, 3, 2, 5, 4, 9, 3, 5, 2, 2, 7, 2, 4, 4, 8, 8, 7, 4, 7]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [24],    # Example TBF
    'K%': [0.2168]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 9 10 11 12]
# Predicted Strikeouts: [2.71 6.   1.   1.61]
# Actual Strikeouts: [2 7 3 2]
# Mean Squared Error: 1.414397041163216
#
# Test Indices: [13 14 15 16]
# Predicted Strikeouts: [5.91 3.   7.62 2.  ]
# Actual Strikeouts: [5 4 9 3]
# Mean Squared Error: 1.1814998062994988
#
# Test Indices: [17 18 19 20]
# Predicted Strikeouts: [4.72 2.   1.66 6.  ]
# Actual Strikeouts: [5 2 2 7]
# Mean Squared Error: 0.29919803160613867
#
# Test Indices: [21 22 23 24]
# Predicted Strikeouts: [2.   3.19 3.19 7.02]
# Actual Strikeouts: [2 4 4 8]
# Mean Squared Error: 0.5713532594834589
#
# Test Indices: [25 26 27 28]
# Predicted Strikeouts: [8.  6.  3.8 6. ]
# Actual Strikeouts: [8 7 4 7]
# Mean Squared Error: 0.50973791430944
#
# Average Mean Squared Error across all folds: 0.7952372105723505
# Predicted Strikeouts for Next Game: 4.999957084655762

# %% [markdown]
# #DAVID FESTA

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [23, 24, 19, 19, 16, 21, 16, 21, 21, 18, 18],
    'K%': [0.087, 0.25, 0.316, 0.474, 0.188, 0.286, 0.313, 0.333, 0.333, 0.222, 0.222],
    'STRIKEOUT': [2, 6, 6, 9, 3, 6, 5, 7, 7, 4, 4]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [20],    # Example TBF
    'K%': [0.29]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [6]
# Predicted Strikeouts: [5.93]
# Actual Strikeouts: [5]
# Mean Squared Error: 0.8663947813365667
#
# Test Indices: [7]
# Predicted Strikeouts: [6.]
# Actual Strikeouts: [7]
# Mean Squared Error: 1.0002422479456072
#
# Test Indices: [8]
# Predicted Strikeouts: [7.]
# Actual Strikeouts: [7]
# Mean Squared Error: 2.3428810891346075e-08
#
# Test Indices: [9]
# Predicted Strikeouts: [3.]
# Actual Strikeouts: [4]
# Mean Squared Error: 0.9998850855463957
#
# Test Indices: [10]
# Predicted Strikeouts: [4.]
# Actual Strikeouts: [4]
# Mean Squared Error: 3.4583536034915596e-10
#
# Average Mean Squared Error across all folds: 0.5733044277206432
# Predicted Strikeouts for Next Game: 5.999953269958496

# %% [markdown]
# #GEORGE KIRBY

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [24, 23, 20, 22, 21, 24, 22, 20, 27, 27, 25, 24, 22, 26, 23, 25, 21, 26, 26, 22, 23, 27, 25, 23, 25, 24, 25, 24, 23, 22, 21],
    'K%': [0.333, 0.087, 0.15, 0.273, 0.333, 0.5, 0.136, 0.2, 0.222, 0.111, 0.12, 0.333, 0.409, 0.154, 0.261, 0.2, 0.333, 0.192, 0.308, 0.318, 0.261, 0.259, 0.08, 0.304, 0.2, 0.208, 0.12, 0.083, 0.391, 0.182, 0.143],
    'STRIKEOUT': [8, 2, 3, 6, 7, 12, 3, 4, 6, 3, 3, 8, 9, 4, 6, 5, 7, 5, 8, 7, 6, 7, 2, 7, 5, 5, 3, 2, 9, 4, 3]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [24],    # Example TBF
    'K%': [0.2044]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 6  7  8  9 10]
# Predicted Strikeouts: [3.17 3.   4.24 4.24 4.24]
# Actual Strikeouts: [3 4 6 3 3]
# Mean Squared Error: 1.4400833722227162
#
# Test Indices: [11 12 13 14 15]
# Predicted Strikeouts: [8.   7.6  3.   6.41 4.02]
# Actual Strikeouts: [8 9 4 6 5]
# Mean Squared Error: 0.8208094812041054
#
# Test Indices: [16 17 18 19 20]
# Predicted Strikeouts: [7. 4. 6. 6. 6.]
# Actual Strikeouts: [7 5 8 7 6]
# Mean Squared Error: 1.199808132217686
#
# Test Indices: [21 22 23 24 25]
# Predicted Strikeouts: [6.   2.18 6.   5.   5.  ]
# Actual Strikeouts: [7 2 7 5 5]
# Mean Squared Error: 0.40663300070706326
#
# Test Indices: [26 27 28 29 30]
# Predicted Strikeouts: [3.   2.   7.52 3.93 3.  ]
# Actual Strikeouts: [3 2 9 4 3]
# Mean Squared Error: 0.44184743261038195
#
# Average Mean Squared Error across all folds: 0.8618362837923905
# Predicted Strikeouts for Next Game: 4.845577239990234

# %% [markdown]
# #JUSTIN VERLANDER

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [21, 20, 27, 26, 25, 20, 28, 25, 24, 23, 20, 22, 26, 19, 21],
    'K%': [0.19, 0.35, 0.074, 0.077, 0.32, 0.15, 0.321, 0.36, 0.167, 0.13, 0.3, 0.136, 0.115, 0, 0.095],
    'STRIKEOUT': [4, 7, 2, 2, 8, 3, 9, 9, 4, 3, 6, 3, 3, 0, 2]
}

# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.18]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6]
# Predicted Strikeouts: [4. 8.]
# Actual Strikeouts: [3 9]
# Mean Squared Error: 1.004790530800392
#
# Test Indices: [7 8]
# Predicted Strikeouts: [8.   2.91]
# Actual Strikeouts: [9 4]
# Mean Squared Error: 1.090847768147455
#
# Test Indices: [ 9 10]
# Predicted Strikeouts: [2.99 3.99]
# Actual Strikeouts: [3 6]
# Mean Squared Error: 2.0196302892238975
#
# Test Indices: [11 12]
# Predicted Strikeouts: [3. 2.]
# Actual Strikeouts: [3 3]
# Mean Squared Error: 0.4993512415709631
#
# Test Indices: [13 14]
# Predicted Strikeouts: [2. 2.]
# Actual Strikeouts: [0 2]
# Mean Squared Error: 2.001275469007169
#
# Average Mean Squared Error across all folds: 1.3231790597499753
# Predicted Strikeouts for Next Game: 3.9999499320983887

# %% [markdown]
# #TYLER ANDERSON

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [26, 25, 20, 27, 24, 24, 28, 27, 25, 31, 23, 26, 26, 25, 27, 25, 22, 27, 24, 22, 27, 26, 22, 28, 30, 23, 21, 19, 25],
    'K%': [0.192, 0.12, 0.2, 0.074, 0.292, 0.25, 0.179, 0.148, 0.16, 0.129, 0.174, 0.077, 0.115, 0.2, 0.185, 0.08, 0.091, 0.37, 0.167, 0.364, 0.37, 0.115, 0.318, 0.286, 0.067, 0.13, 0.143, 0.368, 0.16],
    'STRIKEOUT': [5, 3, 4, 2, 7, 6, 5, 4, 4, 4, 4, 2, 3, 5, 5, 2, 2, 10, 4, 8, 10, 3, 7, 8, 2, 3, 3, 7, 4]
}
# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [25],    # Example TBF
    'K%': [0.1841]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 9 10 11 12]
# Predicted Strikeouts: [3.1  3.94 2.   2.  ]
# Actual Strikeouts: [4 4 2 3]
# Mean Squared Error: 0.4522020314731492
#
# Test Indices: [13 14 15 16]
# Predicted Strikeouts: [4.99 5.   2.   2.  ]
# Actual Strikeouts: [5 5 2 2]
# Mean Squared Error: 8.057728877020054e-06
#
# Test Indices: [17 18 19 20]
# Predicted Strikeouts: [7. 4. 7. 7.]
# Actual Strikeouts: [10  4  8 10]
# Mean Squared Error: 4.75460587627407
#
# Test Indices: [21 22 23 24]
# Predicted Strikeouts: [3.   6.98 7.06 2.  ]
# Actual Strikeouts: [3 7 8 2]
# Mean Squared Error: 0.2194210631913336
#
# Test Indices: [25 26 27 28]
# Predicted Strikeouts: [3.98 3.81 7.99 4.  ]
# Actual Strikeouts: [3 3 7 4]
# Mean Squared Error: 0.6484187029485184
#
# Average Mean Squared Error across all folds: 1.2149311463231895
# Predicted Strikeouts for Next Game: 4.999912261962891

# %% [markdown]
# #COLIN REA

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [22, 25, 24, 23, 25, 25, 22, 25, 24, 21, 23, 23, 23, 22, 25, 24, 21, 21, 25, 29, 25, 27, 19, 19, 23],
    'K%': [0.091, 0.12, 0.25, 0.13, 0.16, 0.2, 0.091, 0.2, 0.208, 0.238, 0.174, 0.261, 0, 0.364, 0.16, 0.125, 0.381, 0.286, 0.36, 0.138, 0.2, 0.185, 0.263, 0.211, 0.043],
    'STRIKEOUT': [2, 3, 6, 3, 4, 5, 2, 5, 5, 5, 4, 6, 0, 8, 4, 3, 8, 6, 9, 4, 5, 5, 5, 4, 1]
}
# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.17]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6 7 8]
# Predicted Strikeouts: [4. 2. 4. 6.]
# Actual Strikeouts: [5 2 5 5]
# Mean Squared Error: 0.7485514266992368
#
# Test Indices: [ 9 10 11 12]
# Predicted Strikeouts: [5. 4. 6. 3.]
# Actual Strikeouts: [5 4 6 0]
# Mean Squared Error: 2.250008446020175
#
# Test Indices: [13 14 15 16]
# Predicted Strikeouts: [6. 4. 3. 6.]
# Actual Strikeouts: [8 4 3 8]
# Mean Squared Error: 2.001226615039755
#
# Test Indices: [17 18 19 20]
# Predicted Strikeouts: [7.21 6.   3.   5.  ]
# Actual Strikeouts: [6 9 4 5]
# Mean Squared Error: 2.8667375739314735
#
# Test Indices: [21 22 23 24]
# Predicted Strikeouts: [4. 6. 5. 0.]
# Actual Strikeouts: [5 5 4 1]
# Mean Squared Error: 0.9992812418903201
#
# Average Mean Squared Error across all folds: 1.7731610607161918
# Predicted Strikeouts for Next Game: 3.9902918338775635

# %% [markdown]
# #ZAC GALLEN

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [21, 22, 23, 23, 25, 19, 22, 23, 27, 27, 1, 19, 19, 24, 20, 24, 27, 25, 29, 21, 25, 23, 24, 21, 19, 23],
    'K%': [0.143, 0.273, 0.435, 0.304, 0.24, 0.158, 0.273, 0.174, 0.37, 0.185, 0, 0.368, 0.211, 0.167, 0.05, 0.167, 0.222, 0.24, 0.138, 0.143, 0.12, 0.391, 0.292, 0.381, 0.368, 0.304],
    'STRIKEOUT': [3, 6, 10, 7, 6, 3, 6, 4, 10, 5, 0, 7, 4, 4, 1, 4, 6, 6, 4, 3, 3, 9, 7, 8, 7, 7]
}
# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22],    # Example TBF
    'K%': [0.34]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [6 7 8 9]
# Predicted Strikeouts: [6. 6. 7. 6.]
# Actual Strikeouts: [ 6  4 10  5]
# Mean Squared Error: 3.5002245945527193
#
# Test Indices: [10 11 12 13]
# Predicted Strikeouts: [3.   7.   3.89 4.  ]
# Actual Strikeouts: [0 7 4 4]
# Mean Squared Error: 2.254167681515767
#
# Test Indices: [14 15 16 17]
# Predicted Strikeouts: [3. 4. 5. 6.]
# Actual Strikeouts: [1 4 6 6]
# Mean Squared Error: 1.2503948742401008
#
# Test Indices: [18 19 20 21]
# Predicted Strikeouts: [ 1.  3.  1. 10.]
# Actual Strikeouts: [4 3 3 9]
# Mean Squared Error: 3.4970627376181085
#
# Test Indices: [22 23 24 25]
# Predicted Strikeouts: [6. 9. 7. 7.]
# Actual Strikeouts: [7 8 7 7]
# Mean Squared Error: 0.500929938783031
#
# Average Mean Squared Error across all folds: 2.2005559653419455
# Predicted Strikeouts for Next Game: 6.999786853790283

# %% [markdown]
# #MICHAEL WACHA

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    "TBF": [19, 23, 27, 24, 24, 26, 21, 27, 23, 26, 22, 21, 19, 25, 24, 23, 24, 20, 27, 28, 27, 22, 24, 29, 20, 23, 22],
    "K%": [0.263, 0.348, 0.148, 0.167, 0.167, 0.115, 0.143, 0.222, 0.304, 0.115, 0.318, 0.095, 0.263, 0.24, 0.333, 0.13, 0.292, 0.05, 0.185, 0.071, 0.222, 0.409, 0.208, 0.241, 0.15, 0.304, 0.364],
    "STRIKEOUT": [5, 8, 4, 4, 4, 3, 3, 6, 7, 3, 7, 2, 5, 6, 8, 3, 7, 1, 5, 2, 6, 9, 5, 7, 3, 7, 8]
}
# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [24],    # Example TBF
    'K%': [0.24]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 7  8  9 10]
# Predicted Strikeouts: [4.  6.3 3.  6.3]
# Actual Strikeouts: [6 7 3 7]
# Mean Squared Error: 1.247344880230699
#
# Test Indices: [11 12 13 14]
# Predicted Strikeouts: [3. 5. 6. 7.]
# Actual Strikeouts: [2 5 6 8]
# Mean Squared Error: 0.5003052725343196
#
# Test Indices: [15 16 17 18]
# Predicted Strikeouts: [3.   6.51 2.   4.  ]
# Actual Strikeouts: [3 7 1 5]
# Mean Squared Error: 0.5595961670341154
#
# Test Indices: [19 20 21 22]
# Predicted Strikeouts: [1.45 6.   8.   5.01]
# Actual Strikeouts: [2 6 9 5]
# Mean Squared Error: 0.3265118805937881
#
# Test Indices: [23 24 25 26]
# Predicted Strikeouts: [6.   3.45 7.   8.  ]
# Actual Strikeouts: [7 3 7 8]
# Mean Squared Error: 0.3013375979898143
#
# Average Mean Squared Error across all folds: 0.5870191596765473
# Predicted Strikeouts for Next Game: 5.243490695953369

# %% [markdown]
# #BEN LIVELY

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [19, 23, 18, 24, 27, 23, 22, 25, 21, 18, 20, 22, 24, 25, 23, 22, 23, 24, 22, 23, 20, 24, 27, 24, 20, 7, 20],
    'K%': [0.368, 0.304, 0.278, 0.208, 0.074, 0.217, 0.318, 0.2, 0.19, 0.056, 0.2, 0.182, 0.208, 0.24, 0.174, 0.318,
           0.087, 0.25, 0.182, 0.087, 0.05, 0.208, 0.148, 0.125, 0.15, 0.286, 0.1],
    'STRIKEOUT': [7, 7, 5, 5, 2, 5, 7, 5, 4, 1, 4, 4, 5, 6, 4, 7, 2, 6, 4, 2, 1, 5, 4, 3, 3, 2, 2]
}
# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22],    # Example TBF
    'K%': [0.19]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 7  8  9 10]
# Predicted Strikeouts: [5. 5. 5. 5.]
# Actual Strikeouts: [5 4 1 4]
# Mean Squared Error: 4.500158789575153
#
# Test Indices: [11 12 13 14]
# Predicted Strikeouts: [2.   5.   5.02 2.  ]
# Actual Strikeouts: [4 5 6 4]
# Mean Squared Error: 2.2400221155827467
#
# Test Indices: [15 16 17 18]
# Predicted Strikeouts: [7.   2.   5.67 4.  ]
# Actual Strikeouts: [7 2 6 4]
# Mean Squared Error: 0.026719321301939658
#
# Test Indices: [19 20 21 22]
# Predicted Strikeouts: [2.   1.59 5.   2.  ]
# Actual Strikeouts: [2 1 5 4]
# Mean Squared Error: 1.0870623048504093
#
# Test Indices: [23 24 25 26]
# Predicted Strikeouts: [2.   3.83 5.   1.1 ]
# Actual Strikeouts: [3 3 2 2]
# Mean Squared Error: 2.874998449513072
#
# Average Mean Squared Error across all folds: 2.145792196164664
# Predicted Strikeouts for Next Game: 3.9998512268066406

# %% [markdown]
# #kyle gibson

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [25, 26, 25, 24, 25, 27, 26, 23, 27, 18, 22, 25, 26, 24, 21, 20, 23, 23, 24, 25, 27, 25, 23, 22, 23, 27, 26, 23],
    'K%': [0.16, 0.192, 0.08, 0.125, 0.24, 0.333, 0.154, 0.304, 0.111, 0.167, 0.273, 0.32, 0.269, 0.25, 0.19, 0.4, 0.348, 0.13, 0.25, 0, 0.259, 0.24, 0.261, 0.227, 0.087, 0.222, 0.346, 0.043],
    'STRIKEOUT': [4, 5, 2, 3, 6, 9, 4, 7, 3, 3, 6, 8, 7, 6, 4, 8, 8, 3, 6, 0, 7, 6, 6, 5, 2, 6, 9, 1]
}
# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [24],    # Example TBF
    'K%': [0.24]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 8  9 10 11]
# Predicted Strikeouts: [2.01 4.   6.   8.23]
# Actual Strikeouts: [3 3 6 8]
# Mean Squared Error: 0.5110225572783094
#
# Test Indices: [12 13 14 15]
# Predicted Strikeouts: [6.22 6.   3.   8.27]
# Actual Strikeouts: [7 6 4 8]
# Mean Squared Error: 0.42118205317378
#
# Test Indices: [16 17 18 19]
# Predicted Strikeouts: [8.21 3.   6.   2.  ]
# Actual Strikeouts: [8 3 6 0]
# Mean Squared Error: 1.0127561276306096
#
# Test Indices: [20 21 22 23]
# Predicted Strikeouts: [6.81 6.   6.   5.1 ]
# Actual Strikeouts: [7 6 6 5]
# Mean Squared Error: 0.011308672268398823
#
# Test Indices: [24 25 26 27]
# Predicted Strikeouts: [2.   5.37 8.8  0.  ]
# Actual Strikeouts: [2 6 9 1]
# Mean Squared Error: 0.3600813108573958
#
# Average Mean Squared Error across all folds: 0.46327014424169877
# Predicted Strikeouts for Next Game: 5.999515533447266

# %% [markdown]
# #GERRITH COLE

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [16, 21, 20, 22, 24, 25, 27, 23, 23, 23, 23, 23, 23, 23, 22],
    'K%': [0.313, 0, 0.3, 0.364, 0.292, 0.32, 0.148, 0.174, 0.435, 0.348, 0.087, 0.304, 0.391, 0.304, 0.091],
    'STRIKEOUT': [5, 0, 6, 8, 7, 8, 4, 4, 10, 8, 2, 7, 9, 7, 2]
}
# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.2448]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [5 6]
# Predicted Strikeouts: [7. 0.]
# Actual Strikeouts: [8 4]
# Mean Squared Error: 8.493911170174512
#
# Test Indices: [7 8]
# Predicted Strikeouts: [4. 8.]
# Actual Strikeouts: [ 4 10]
# Mean Squared Error: 2.00099920127343
#
# Test Indices: [ 9 10]
# Predicted Strikeouts: [8.  2.6]
# Actual Strikeouts: [8 2]
# Mean Squared Error: 0.18030770359928283
#
# Test Indices: [11 12]
# Predicted Strikeouts: [7.02 8.  ]
# Actual Strikeouts: [7 9]
# Mean Squared Error: 0.500239948492208
#
# Test Indices: [13 14]
# Predicted Strikeouts: [7. 2.]
# Actual Strikeouts: [7 2]
# Mean Squared Error: 3.544541016253788e-07
#
# Average Mean Squared Error across all folds: 2.235091675598707
# Predicted Strikeouts for Next Game: 3.9999454021453857

# %% [markdown]
# #JOE. MUSGROVE

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [17, 26, 22, 21, 26, 25, 21, 21, 15, 20, 17, 17, 22, 25, 23, 22, 22],
    'K%': [0.118, 0.115, 0.318, 0.238, 0.115, 0.12, 0.19, 0.429, 0.2, 0.25, 0.059, 0.353, 0.409, 0.12, 0.348, 0.318, 0.364],
    'STRIKEOUT': [2, 3, 7, 5, 3, 3, 4, 9, 3, 5, 1, 6, 9, 3, 8, 7, 8]
}
# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [22],    # Example TBF
    'K%': [0.26]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [7 8]
# Predicted Strikeouts: [5.01 2.68]
# Actual Strikeouts: [9 3]
# Mean Squared Error: 8.017109168545403
#
# Test Indices: [ 9 10]
# Predicted Strikeouts: [4.19 2.  ]
# Actual Strikeouts: [5 1]
# Mean Squared Error: 0.8313878929929217
#
# Test Indices: [11 12]
# Predicted Strikeouts: [8.45 7.  ]
# Actual Strikeouts: [6 9]
# Mean Squared Error: 5.007346883710852
#
# Test Indices: [13 14]
# Predicted Strikeouts: [3. 7.]
# Actual Strikeouts: [3 8]
# Mean Squared Error: 0.49999094848431014
#
# Test Indices: [15 16]
# Predicted Strikeouts: [7. 8.]
# Actual Strikeouts: [7 8]
# Mean Squared Error: 1.253179220839229e-06
#
# Average Mean Squared Error across all folds: 2.8711672293825417
# Predicted Strikeouts for Next Game: 4.484875202178955

# %% [markdown]
# #GARRETH CROCHET

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    "TBF": [23, 25, 19, 21, 16, 21, 18, 21, 23, 21, 21, 22, 25, 24, 25, 27, 21, 26, 21, 6, 18, 18, 16, 16, 16, 16, 13, 12, 15],
    "K%": [0.348, 0.32, 0.263, 0.476, 0.188, 0.286, 0.389, 0.286, 0.478, 0.286, 0.19, 0.5, 0.32, 0.417, 0.52, 0.296, 0.286, 0.423, 0.238, 0.667, 0.389, 0.167, 0.125, 0.313, 0.563, 0.25, 0.615, 0.25, 0.267],
    "STRIKEOUT": [8, 8, 5, 10, 3, 6, 7, 6, 11, 6, 4, 11, 8, 10, 13, 8, 6, 11, 5, 4, 7, 3, 2, 5, 9, 4, 8, 3, 4]
}
# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [19],    # Example TBF
    'K%': [0.2747]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [ 9 10 11 12]
# Predicted Strikeouts: [ 6.    5.99 11.    8.  ]
# Actual Strikeouts: [ 6  4 11  8]
# Mean Squared Error: 0.9917377097174835
#
# Test Indices: [13 14 15 16]
# Predicted Strikeouts: [ 8.   11.    6.05  6.  ]
# Actual Strikeouts: [10 13  8  6]
# Mean Squared Error: 2.947239844412536
#
# Test Indices: [17 18 19 20]
# Predicted Strikeouts: [10.7   4.   11.47  7.  ]
# Actual Strikeouts: [11  5  4  7]
# Mean Squared Error: 14.205278596723304
#
# Test Indices: [21 22 23 24]
# Predicted Strikeouts: [4.4  3.   5.43 7.52]
# Actual Strikeouts: [3 2 5 9]
# Mean Squared Error: 1.333098193350338
#
# Test Indices: [25 26 27 28]
# Predicted Strikeouts: [4.42 4.   3.89 3.89]
# Actual Strikeouts: [4 8 3 4]
# Mean Squared Error: 4.2418556645987735
#
# Average Mean Squared Error across all folds: 4.743842001760487
# Predicted Strikeouts for Next Game: 5.285552501678467

# %% [markdown]
# #KYLE FREELAND

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from xgboost import XGBRegressor
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.metrics import mean_squared_error

# Input data
data = {
    'TBF': [17, 23, 24, 23, 20, 28, 28, 27, 24, 21, 25, 20, 15, 24, 27, 25, 20, 22, 29],
    'K%': [0.118, 0.087, 0.083, 0.13, 0.2, 0.107, 0.179, 0.333, 0.167, 0.381, 0.24, 0.35, 0.067, 0.125, 0.111, 0.2, 0.25, 0.182, 0.103],
    'STRIKEOUT': [2, 2, 2, 3, 4, 3, 5, 9, 4, 8, 6, 7, 1, 3, 3, 5, 5, 4, 3]
}
# Create DataFrame
df = pd.DataFrame(data)

# Features and target variable
X = df[['TBF', 'K%']]
y = df['STRIKEOUT']

# Initialize XGBoost Regressor
model = XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)

# TimeSeriesSplit for backtesting
tscv = TimeSeriesSplit(n_splits=5)

# List to store Mean Squared Errors for each fold
mse_scores = []

# Perform backtesting
for train_index, test_index in tscv.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

    # Train the model
    model.fit(X_train, y_train)

    # Predict and calculate MSE
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    mse_scores.append(mse)

    print(f'Test Indices: {test_index}')
    print(f'Predicted Strikeouts: {np.round(y_pred, 2)}')
    print(f'Actual Strikeouts: {y_test.values}')
    print(f'Mean Squared Error: {mse}\n')

print(f'Average Mean Squared Error across all folds: {np.mean(mse_scores)}')

# Fit model on entire dataset
model.fit(X, y)

# Predict for next game (example input)
next_game_data = {
    'TBF': [23],    # Example TBF
    'K%': [0.20]  # Example K%
}

next_game_df = pd.DataFrame(next_game_data)
predicted_strikeouts = model.predict(next_game_df)
print(f'Predicted Strikeouts for Next Game: {predicted_strikeouts[0]}')
# Out:
# Test Indices: [4 5 6]
# Predicted Strikeouts: [3. 2. 3.]
# Actual Strikeouts: [4 3 5]
# Mean Squared Error: 2.0017544915700114
#
# Test Indices: [7 8 9]
# Predicted Strikeouts: [5. 3. 4.]
# Actual Strikeouts: [9 4 8]
# Mean Squared Error: 11.007619681947668
#
# Test Indices: [10 11 12]
# Predicted Strikeouts: [4.04 8.   2.  ]
# Actual Strikeouts: [6 7 1]
# Mean Squared Error: 1.9508424917876444
#
# Test Indices: [13 14 15]
# Predicted Strikeouts: [2.   3.   4.95]
# Actual Strikeouts: [3 3 5]
# Mean Squared Error: 0.3339022029492374
#
# Test Indices: [16 17 18]
# Predicted Strikeouts: [5.83 4.21 2.64]
# Actual Strikeouts: [5 4 3]
# Mean Squared Error: 0.28645872062946864
#
# Average Mean Squared Error across all folds: 3.116115517776806
# Predicted Strikeouts for Next Game: 4.146782875061035
